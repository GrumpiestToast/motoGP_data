# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
import time
from collections import defaultdict
import requests
import os

# %%
# Headers for all the data we will be scraping in this notebook
headers = ['Year','TRK','Track','Category','Session','Date','Track_Condition','Track_Temp','Air_Temp',
           'Humidity','Position','Points','Rider_Number','Rider_Name','Nationality','Team_Name',
           'Bike','Avg_Speed','Time']
headers2 = ['Track', "Trk Length", 'Left_Corners', 'Right_Corners', 'track_width', 'length of longest straight', 'MotoGP_avg_speed', 'GP_distance', 'Moto2_distance', 'Moto3_distance'] 


#had to remove 2002 - 2004
years = ['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

base_url = 'http://www.motogp.com/en/Results+Statistics/'

# %%
def soup_stuff(url):
    """Returns a BeautifulSoup object for the provided url"""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    return soup

# %%
def get_date(soup):
    """ Returns the date of the race, or 'n/a' if 
        information does not exist in the provided soup """
    find = soup.find(class_='padbot5')
    if find is None:
        r = 'n/a'
    else:
        r = ','.join(find.text.replace(',',' ').split()[-3:])
    return r

# %%
def get_tr_con(soup):
    """ Returns the track condition during a race, or 'n/a' if 
        information does not exist in the provided soup """
    find = soup.find(class_='sprite_weather track_condition')
    if find is None:
        r = 'n/a'
    else:
        r = find.findNext().text.split()[2]
    return r

# %%
def get_tr_tmp(soup):
    """ Returns the track temperature during a race, or 'n/a' if 
        information does not exist in the provided soup """
    find = soup.find(class_='sprite_weather ground')
    if find is None:
        r = 'n/a'
    else:
        r = find.findNext().text.split()[1]
        r= r.strip('º')
        r = float(r)
    return r

def get_air_tmp(soup):
    """ Returns the air temperature during a race, or 'n/a' if 
        information does not exist in the provided soup """
    find = soup.find(class_='sprite_weather air')
    if find is None:
        r = 'n/a'
    else:
        r = find.findNext().text.split()[1]
        r= r.strip('º')
        r = float(r)
    return r

def get_humidity(soup):
    """ Returns the track humidity during a race, or 'n/a' if 
        information does not exist in the provided soup """
    find = soup.find(class_='sprite_weather humidity')
    if find is None:
        r = 'n/a'
    else:
        r = find.findNext().text.split()[1]
        r = re.sub('[%]','',r) 
        r = int(r)
    return r

def get_all_races(soup):
    """ Returns all the races that took place in a particular season
        for which the soup was passed in """
    find = soup.find(id='event')
    if find is None:
        r = []
    else:
        r = find.find_all('option')
    return r

def get_all_cats(soup):
    """ Returns all the different categories (MotoGP, Moto2, etc.)
        that took place at a particular track in the provided soup """
    find = soup.find(id='category')
    if find is None:
        r = []
    else:
        r = find.find_all('option')
    return r

def get_race_sessions(soup):
    """ Returns all the different race sessions (RACE, RACE2, etc.)
        that took place at a particular track in the provided soup """
    find = soup.find(id='session')
    r = []
    if find is None:
        return r
    else:
        r2 = find.find_all('option')
        for s in r2:
            if s.text.find('RACE') > -1:
                r.append(s.text.replace('E',''))
        return r

# %%
def get_all_stats(soup, year, trk, track, cat, ssn):
    
    if soup.find('tbody') is None:
        return [dict(zip(headers, [year, trk, track, cat, ssn]+['n/a']*(len(headers)-3)))]
    else:
        riders = soup.find('tbody').find_all('a')
        stats_to_return = []

        # raceday stats
        date = get_date(soup)
        tr_con = get_tr_con(soup)
        tr_tmp = get_tr_tmp(soup)
        air_tmp = get_air_tmp(soup)
        humid = get_humidity(soup)
        
        # rider stats
        for r in riders:
            pos = r.findPrevious().findPrevious().findPrevious().findPrevious().text
            if pos=='':
                pos='crash'
            else:
                pos=int(pos)    
            points = r.findPrevious().findPrevious().findPrevious().text
            if points=='':
                points=0
            else:
                points=float(points)
            r_num = r.findPrevious().findPrevious().text
            if r_num != '':
                r_num = int(r_num)
            r_nam = r.text
            r_nat = r.findNext().text
            team = r.findNext().findNext().text
            bike = r.findNext().findNext().findNext().text
            avgspd = r.findNext().findNext().findNext().findNext().text
            time = r.findNext().findNext().findNext().findNext().findNext().text

            stats_dict = dict(zip(headers, [year, trk, track, cat, ssn, date, tr_con, tr_tmp, air_tmp,
                                            humid, pos, points, r_num, r_nam, r_nat, team,
                                            bike, avgspd, time]))
            stats_to_return.append(stats_dict)

        return stats_to_return

# %%
# loop through all parameters

for yr in reversed(years):
    data_list = []
    soup_yr = soup_stuff(base_url + yr)
    races = get_all_races(soup_yr)
    print(yr)
    
    for rc in races:
        TRK = rc['value']
        Track = rc['title']
        print(TRK, end=", ")
        url_rc = base_url +yr +'/' +TRK +'/'
        soup_rc = soup_stuff(url_rc)
        categories = get_all_cats(soup_rc)
        
        for cat in categories:
            CAT = cat.text
            url_c = base_url +yr +'/' +TRK +'/' + CAT + '/'
            soup_c = soup_stuff(url_c)
            sessions = get_race_sessions(soup_c)
            
            for ssn in sessions:
                SSN = ssn
                url_ssn = base_url +yr +'/' +TRK +'/' + CAT + '/' + SSN + '/Classification'
                soup_ssn = soup_stuff(url_ssn)
                data_list.extend(get_all_stats(soup_ssn, yr, TRK, Track, CAT, SSN))
                time.sleep(1+np.random.random())
    
    df = pd.DataFrame(data_list, columns=headers)
    fn = './Archive/' + yr + '_data.csv'
    df.to_csv(fn)
    print(fn)
    time.sleep(1+np.random.random())

print('>> Scraping complete!')
# Out:
# 2018
# QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, CZE, AUT, GBR, RSM, ARA, THA, JPN, AUS, MAL, VAL, ./Archive/2018_data.csv
# 2017
# QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, CZE, AUT, GBR, RSM, ARA, JPN, AUS, MAL, VAL, ./Archive/2017_data.csv
# 2016
# QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, AUT, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL, ./Archive/2016_data.csv
# 2015
# QAT, AME, ARG, SPA, FRA, ITA, CAT, NED, GER, INP, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL, ./Archive/2015_data.csv
# 2014
# QAT, AME, ARG, SPA, FRA, ITA, CAT, NED, GER, INP, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL, ./Archive/2014_data.csv
# 2013
# QAT, AME, SPA, FRA, ITA, CAT, NED, GER, USA, INP, CZE, GBR, RSM, ARA, MAL, AUS, JPN, VAL, ./Archive/2013_data.csv
# 2012
# QAT, SPA, POR, FRA, CAT, GBR, NED, GER, ITA, USA, INP, CZE, RSM, ARA, JPN, MAL, AUS, VAL, ./Archive/2012_data.csv
# 2011
# QAT, SPA, POR, FRA, CAT, GBR, NED, ITA, GER, USA, CZE, INP, RSM, ARA, JPN, AUS, MAL, VAL, ./Archive/2011_data.csv
# 2010
# QAT, SPA, FRA, ITA, GBR, NED, CAT, GER, USA, CZE, INP, RSM, ARA, JPN, MAL, AUS, POR, VAL, ./Archive/2010_data.csv
# 2009
# QAT, JPN, SPA, FRA, ITA, CAT, NED, USA, GER, GBR, CZE, INP, RSM, POR, AUS, MAL, VAL, ./Archive/2009_data.csv
# 2008
# QAT, SPA, POR, CHN, FRA, ITA, CAT, GBR, NED, GER, USA, CZE, RSM, INP, JPN, AUS,
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      55
# ---> 56     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      57         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002A7E3DDBA58>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='www.motogp.com', port=80): Max retries exceeded with url: /en/Results+Statistics/2008/AUS/250cc/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002A7E3DDBA58>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-90-f715ebedc2a6> in <module>
#      18             CAT = cat.text
#      19             url_c = base_url +yr +'/' +TRK +'/' + CAT + '/'
# ---> 20             soup_c = soup_stuff(url_c)
#      21             sessions = get_race_sessions(soup_c)
#      22
#
# <ipython-input-3-eb88851c18a6> in soup_stuff(url)
#       1 def soup_stuff(url):
#       2     """Returns a BeautifulSoup object for the provided url"""
# ----> 3     response = requests.get(url)
#       4     soup = BeautifulSoup(response.text, 'lxml')
#       5     return soup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.motogp.com', port=80): Max retries exceeded with url: /en/Results+Statistics/2008/AUS/250cc/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002A7E3DDBA58>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
# first, get all tracks from 2002-2018
track_list = []
GPs_list = []
track_names = []

for yr in reversed(years):
    soup_yr = soup_stuff(base_url + yr)
    races = get_all_races(soup_yr)
    print('')
    print(yr, end = " - ")
    
    for rc in races:
        TRK = rc['value']
        Track = rc['title']
        print(TRK, end=", ")
        track_list.append(TRK)
        GPs_list.append(Track.split(' - ')[0])
        track_names.append(Track.split(' - ')[1])
        
    time.sleep(1+np.random.random())
# Out:
# 2018 - QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, CZE, AUT, GBR, RSM, ARA, THA, JPN, AUS, MAL, VAL,
# 2017 - QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, CZE, AUT, GBR, RSM, ARA, JPN, AUS, MAL, VAL,
# 2016 - QAT, ARG, AME, SPA, FRA, ITA, CAT, NED, GER, AUT, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL,
# 2015 - QAT, AME, ARG, SPA, FRA, ITA, CAT, NED, GER, INP, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL,
# 2014 - QAT, AME, ARG, SPA, FRA, ITA, CAT, NED, GER, INP, CZE, GBR, RSM, ARA, JPN, AUS, MAL, VAL,
# 2013 - QAT, AME, SPA, FRA, ITA, CAT, NED, GER, USA, INP, CZE, GBR, RSM, ARA, MAL, AUS, JPN, VAL,
# 2012 - QAT, SPA, POR, FRA, CAT, GBR, NED, GER, ITA, USA, INP, CZE, RSM, ARA, JPN, MAL, AUS, VAL,
# 2011 - QAT, SPA, POR, FRA, CAT, GBR, NED, ITA, GER, USA, CZE, INP, RSM, ARA, JPN, AUS, MAL, VAL,
# 2010 - QAT, SPA, FRA, ITA, GBR, NED, CAT, GER, USA, CZE, INP, RSM, ARA, JPN, MAL, AUS, POR, VAL,
# 2009 - QAT, JPN, SPA, FRA, ITA, CAT, NED, USA, GER, GBR, CZE, INP, RSM, POR, AUS, MAL, VAL,
# 2008 - QAT, SPA, POR, CHN, FRA, ITA, CAT, GBR, NED, GER, USA, CZE, RSM, INP, JPN, AUS, MAL, VAL,
# 2007 - QAT, SPA, TUR, CHN, FRA, ITA, CAT, GBR, NED, GER, USA, CZE, RSM, POR, JPN, AUS, MAL, VAL,
# 2006 - SPA, QAT, TUR, CHN, FRA, ITA, CAT, NED, GBR, GER, USA, CZE, MAL, AUS, JPN, POR, VAL,
# 2005 - SPA, POR, CHN, FRA, ITA, CAT, NED, USA, GBR, GER, CZE, JPN, MAL, QAT, AUS, TUR, VAL,
# 2004 - RSA, SPA, FRA, ITA, CAT, NED, RIO, GER, GBR, CZE, POR, JPN, QAT, MAL, AUS, VAL,
# 2003 - JPN, RSA, SPA, FRA, ITA, CAT, NED, GBR, GER, CZE, POR, RIO, PAC, MAL, AUS, VAL,
# 2002 - JPN, RSA, SPA, FRA, ITA, CAT, NED, GBR, GER, CZE, POR, RIO, PAC, MAL, AUS, VAL,

# %%
# extract the unique ones 
combined_list = []
for index, item in enumerate(track_list):
    combined_list.append(item+' - '+track_names[index])
combined_track_set = set(combined_list)

# %%
#combined_track_set = combined_track_set.remove("JPN - Suzuka Circuit")
#combined_track_set = combined_track_set.remove("RSA - Phakisa Freeway")
#combined_track_set = combined_track_set.remove("ITA - Autodromo Internazionale del Mugello':'Italy")
#combined_track_set = combined_track_set.remove(')

# %%
#Manually inserting tracks that lack a URL 

track_url_dict = {'AME - Circuit Of The Americas':'Americas',
                  'ARA - MotorLand Aragón':'Aragon',
                  'ARG - Termas de Río Hondo':'Argentina',
                  'AUS - Phillip Island':'Australia',
                  'AUT - Red Bull Ring – Spielberg':'Austria',
                  'CAT - Circuit de Barcelona-Catalunya':'Catalunya',
                  'CHN - Shanghai Circuit':0,
                  'CZE - Automotodrom Brno':'Czech+Republic',
                  'FRA - Le Mans':'France',
                  'GBR - Donington Park Circuit':0,
                  'GBR - Silverstone Circuit':'Great+Britain',
                  'GER - Sachsenring':'Germany',
                  'INP - Indianapolis Motor Speedway':0,
                  'ITA - Autodromo del Mugello':'Italy',
                  'JPN - Twin Ring Motegi':'Japan',
                  'MAL - Sepang International Circuit':'Malaysia',
                  'NED - TT Circuit Assen':'Netherlands',
                  'THA - Chang International Circuit' : 'Thailand',
                  'POR - Estoril Circuit':0,
                  'QAT - Losail International Circuit':'Qatar',
                  'RIO - Nelson Piquet Circuit': 0,
                  'RSM - Misano World Circuit Marco Simoncelli':'San+Marino',
                  'SPA - Circuito de Jerez':'Spain',
                  'TUR - Istanbul Circuit':0,
                  'USA - Mazda Raceway Laguna Seca':0,
                  'VAL - Circuit Ricardo Tormo':'Valencia'    
}

# %%
# functions to get basic track info
def get_GP_info(track_url_str):
    """
    Returns a list with track length, number of left corners, number of right corners,
    track width, and length of longest straight. For any unavailable values, it returns
    'n/a' instead of a float or int.
    """
    url = 'http://www.motogp.com/en/event/' + track_url_str + '#info-track'
    soupy = soup_stuff(url)
    attributes = soupy.find(id='circuit_numbers').find_all(class_='circuit_number_content')
    strs = []
    list_data = []
    
    for s in range(len(attributes)):
        strs.append(attributes[s].text)

    if float(strs[0].split()[0])==0:
        list_data.append('n/a')
    else:
        list_data.append(float(strs[0].split()[0]))

    if strs[1]=='':
        list_data.append('n/a')
    else:
        list_data.append(int(strs[1]))
    
    if strs[2]=='':
        list_data.append('n/a')
    else:
        list_data.append(int(strs[2]))
    
    if len(strs[3].split())==1:
        list_data.append('n/a')
    else:
        list_data.append(float(strs[3].split()[0]))
    
    if len(strs[4].split())==1:
        list_data.append('n/a')
    else:
        list_data.append(float(strs[4].split()[0]))

    return list_data

def get_GP_info_additional(track_url_str):
    """
    Returns MotoGP average speed, MotoGP distance, Moto2 distance,
    and Moto3 distance for the particular track. If data does not exist,
    it returns 'n/a' in place of a float or int.
    """
    url = 'http://www.motogp.com/en/event/' + track_url_str + '#info-track'
    soupy = soup_stuff(url)
    
    # MotoGP average speed
    avg_speed_str = soupy.find(class_='c-statistics__speed-item').text
    if avg_speed_str == '-' or avg_speed_str == '':
        avg_speed = 'n/a'
    else:
        avg_speed = float(avg_speed_str)
    
    attributes = soupy.find(class_='c-event__row-item col-xs-12 col-lg-7 col-lg-pull-5').find_all(class_='c-laps__item')
    
    # MotoGP distance
    GP_dist = attributes[1].text.split()[0]
    GP_dist = float(GP_dist)
    if GP_dist==0: GP_dist='n/a'
        
     # Moto2 distance
    m2_dist = attributes[4].text.split()[0]
    m2_dist = float(m2_dist)    
    if m2_dist==0: m2_dist='n/a'
        
     # Moto3 distance
    m3_dist = attributes[7].text.split()[0]
    m3_dist = float(m3_dist)   
    if m3_dist==0: m3_dist='n/a'
        
    return [avg_speed, GP_dist, m2_dist, m3_dist]

# %%
# make a list of dictionaries for track information
headers_2 = ['GP','track_length_km','l_corners','r_corners',
           'width_m','straight_m','GP_avg_speed','gp_dist',
           'm2_dist','m3_dist']

track_data = []
for track in combined_track_set:
    if track_url_dict[track] != 0:
        print('//', end='')
        l_GP, L_c, R_c, wid, strt = get_GP_info(track_url_dict[track])
        GP_avg_spd, gp_d, m2_d, m3_d = get_GP_info_additional(track_url_dict[track])
        track_dict = dict(zip(headers2, [track,l_GP,L_c,R_c,wid,strt,GP_avg_spd,gp_d,m2_d,m3_d]))
        track_data.append(track_dict)
        time.sleep(1+np.random.random())
print('Complete!')
# Out:
# //////////////////////////////Complete!

# %%
# url = 'http://www.motogp.com/en/event/Qatar'
# soupy = soup_stuff(url)
# attributes = soupy.find(class_='c-event__row-item col-xs-12 col-lg-7 col-lg-pull-5').find_all(class_='c-laps__item')
# GP_dist = float(attributes[1].text.split()[0])
# if GP_dist==0: GP_dist='n/a'
# print(GP_dist)

# %%
# combined_track_set.remove('AUS - Phillip Island')
# combined_track_set.remove('AUT - Red Bull Ring')
# combined_track_set.remove('RIO - Nelson Piquet Circuit')
# combined_track_set.remove('THA - Chang International Circuit')
# combined_track_set.remove('PAC - Twin Ring Motegi')
# combined_track_set.remove('JPN - Suzuka Circuit')
#combined_track_set.remove('RSA - Phakisa Freeway')
#combined_track_set.remove('ITA - Autodromo Internazionale del Mugello')

# %%
# manually add in the info for tracks which have a 0 in the track_url_dict
# information is from archived PDFs like the one at this following link
# http://resources.motogp.com/files/results/2006/CHN/circuit+information.pdf?v1_96143780


dict_austria = {'Track' : 'AUT - Red Bull Ring', 'MotoGP_avg_speed' : 182.8, 'GP_distance' : 120.9, 
                'Left_Corners' : 3.0, 'Moto2_distance' : 108.0, ' Moto3_distance' : 99.3, 'Right_Corners' : 7.0, 
                'length of longest straight' : 626.0, 'Trk Length':4.3, 'track_width':13.0}

dict_shanghai = {'Track' : 'CHN - Shanghai Circuit', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 7.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 7.0, 
                'length of longest straight' : 1202.0, 'Trk Length':5.281, 'track_width':14.0}

dict_donington = {'Track' : 'GBR - Donington Park Circuit', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 4.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 7.0, 
                'length of longest straight' : 564.0, 'Trk Length':4.023, 'track_width':10.0}

dict_indianapolis = {'Track' : 'INP - Indianapolis Motor Speedway', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 10.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 6.0, 
                'length of longest straight' : 644.0, 'Trk Length':4.216, 'track_width':16.0}

dict_estoril = {'Track' : 'POR - Estoril Circuitt', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 4.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 9.0, 
                'length of longest straight' : 986.0, 'Trk Length':4.182, 'track_width':14.0}

dict_istanbul = {'Track' : 'TUR - Istanbul Circuit', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 8.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 6.0, 
                'length of longest straight' : 720.0, 'Trk Length':5.340, 'track_width':21.0}

dict_laguna = {'Track' : 'USA - Mazda Raceway Laguna Seca', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 7.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 4.0, 
                'length of longest straight' : 966.0, 'Trk Length':3.610, 'track_width':15.0}

dict_australia = {'Track' : 'AUS - Phillip Island', 'MotoGP_avg_speed' : 176.3, 'GP_distance' : 120.1, 
                'Left_Corners' : 7.0, 'Moto2_distance' : 111.2, ' Moto3_distance' : 102.3, 'Right_Corners' : 5.0, 
                'length of longest straight' : 900.0, 'Trk Length':4.4, 'track_width':13.0}

dict_brazil = {'Track' : 'RIO - Autódromo Internacional Nelson Piquet', 'MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                'Left_Corners' : 6.0 , 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 6.0, 
                'length of longest straight' : 'n/a', 'Trk Length': 5.031, 'track_width':'n/a'}

dict_Thai = {'Track' : 'THA - Chang International Circuit', 'MotoGP_avg_speed' : 177.9, 'GP_distance' : 118.4, 
                'Left_Corners' : 5.0, 'Moto2_distance' : 109.3, ' Moto3_distance' : 100.2, 'Right_Corners' : 7.0, 
                'length of longest straight' : 1000.0, 'Trk Length':4.6, 'track_width':12.0}

dict_motegi = {'Track' : 'PAC - Twin Ring Motegi', 'MotoGP_avg_speed' : 162.2, 'GP_distance' : 115.2, 
                'Left_Corners' : 6.0, 'Moto2_distance' : 105.6, ' Moto3_distance' : 96.0, 'Right_Corners' : 8.0, 
                'length of longest straight' : 762.0, 'Trk Length':4.8, 'track_width':15.0}

dict_italy= {'Track' : 'ITA - Autodromo Internazionale del Mugello','MotoGP_avg_speed' : 174.1, 'GP_distance' : 120.6, 
                'Left_Corners' : 6.0, 'Moto2_distance' : 110.1, ' Moto3_distance' : 104.9, 'Right_Corners' : 9.0, 
                'length of longest straight' : 1141.0, 'Trk Length':5.2, 'track_width':14.0}

dict_africa = {'Track' : 'RSA - Phakisa Freeway','MotoGP_avg_speed' : 174.1, 'GP_distance' : 120.6, 
                'Left_Corners' : 6.0, 'Moto2_distance' : 110.1, ' Moto3_distance' : 104.9, 'Right_Corners' : 9.0, 
                'length of longest straight' : 1141.0, 'Trk Length':5.2, 'track_width':14.0}

dict_suz = {'Track' : 'JPN - Suzuka Circuit','MotoGP_avg_speed' : 'n/a', 'GP_distance' : 'n/a', 
                 'Left_Corners' : 7.0, 'Moto2_distance' : 'n/a', ' Moto3_distance' : 'n/a', 'Right_Corners' : 10.0, 
                 'length of longest straight' : 'n/a', 'Trk Length': 5.8153, 'track_width':'n/a'}


track_data.append(dict_shanghai)
track_data.append(dict_donington)
track_data.append(dict_indianapolis)
track_data.append(dict_estoril)
track_data.append(dict_istanbul)
track_data.append(dict_laguna)
track_data.append(dict_australia)
track_data.append(dict_brazil)
track_data.append(dict_Thai)
track_data.append(dict_motegi)
track_data.append(dict_austria)
track_data.append(dict_italy)
track_data.append(dict_suz)

# %%
#create dataframe from new data
df_tracks = pd.DataFrame(track_data, columns=headers2)

# %%
df_tracks
# Out:
#                                           Track  Trk Length  Left_Corners  \
# 0          CAT - Circuit de Barcelona-Catalunya      4.6000           6.0
# 1                        JPN - Twin Ring Motegi      4.8000           6.0
# 2                             GER - Sachsenring      3.7000          10.0
# 3                 AME - Circuit Of The Americas      5.5000          11.0
# 4                        ARA - MotorLand Aragón      5.1000          10.0
# 5                       CZE - Automotodrom Brno      5.4000           6.0
# 6                        NED - TT Circuit Assen      4.5000           6.0
# 7                   VAL - Circuit Ricardo Tormo      4.0000           9.0
# 8   RSM - Misano World Circuit Marco Simoncelli      4.2000           6.0
# 9            MAL - Sepang International Circuit      5.5000           5.0
# 10           QAT - Losail International Circuit      5.4000           6.0
# 11                    ARG - Termas de Río Hondo      4.8000           5.0
# 12                    GBR - Silverstone Circuit      5.9000           8.0
# 13                                FRA - Le Mans      4.2000           5.0
# 14                      SPA - Circuito de Jerez      4.4000           6.0
# 15                       CHN - Shanghai Circuit      5.2810           7.0
# 16                 GBR - Donington Park Circuit      4.0230           4.0
# 17            INP - Indianapolis Motor Speedway      4.2160          10.0
# 18                       POR - Estoril Circuitt      4.1820           4.0
# 19                       TUR - Istanbul Circuit      5.3400           8.0
# 20              USA - Mazda Raceway Laguna Seca      3.6100           7.0
# 21                         AUS - Phillip Island      4.4000           7.0
# 22  RIO - Autódromo Internacional Nelson Piquet      5.0310           6.0
# 23            THA - Chang International Circuit      4.6000           5.0
# 24                       PAC - Twin Ring Motegi      4.8000           6.0
# 25                          AUT - Red Bull Ring      4.3000           3.0
# 26   ITA - Autodromo Internazionale del Mugello      5.2000           6.0
# 27                         JPN - Suzuka Circuit      5.8153           7.0
#
#     Right_Corners track_width length of longest straight MotoGP_avg_speed  \
# 0             8.0          12                       1047            164.4
# 1             8.0          15                        762            162.2
# 2             3.0          12                        700            160.6
# 3             9.0          15                       1200            158.4
# 4             7.0          15                        968              167
# 5             8.0          15                        636            165.5
# 6            12.0          14                        487            173.1
# 7             5.0          12                        876            139.8
# 8            10.0          14                        530            162.6
# 9            10.0          16                        920              164
# 10           10.0          12                       1068            166.6
# 11            9.0          16                       1076            172.7
# 12           10.0          15                        770              n/a
# 13            9.0          13                        674            161.8
# 14            8.0          11                        607            161.2
# 15            7.0          14                       1202              n/a
# 16            7.0          10                        564              n/a
# 17            6.0          16                        644              n/a
# 18            9.0          14                        986              n/a
# 19            6.0          21                        720              n/a
# 20            4.0          15                        966              n/a
# 21            5.0          13                        900            176.3
# 22            6.0         n/a                        n/a              n/a
# 23            7.0          12                       1000            177.9
# 24            8.0          15                        762            162.2
# 25            7.0          13                        626            182.8
# 26            9.0          14                       1141            174.1
# 27           10.0         n/a                        n/a              n/a
#
#    GP_distance Moto2_distance  Moto3_distance
# 0          111          101.8            97.2
# 1        115.2          105.6            96.0
# 2        110.1          102.8            99.1
# 3        110.3           99.2            93.7
# 4        116.8          106.6            96.5
# 5        113.5          102.7            97.3
# 6        118.1            109            99.9
# 7        108.1          100.1            92.1
# 8        114.1          105.7            97.2
# 9        110.9           99.8            94.2
# 10       118.4          107.6            96.8
# 11       120.2          110.5           100.9
# 12         118          106.2           100.3
# 13         113          104.6            92.1
# 14       110.6          101.7            97.3
# 15         n/a            n/a             NaN
# 16         n/a            n/a             NaN
# 17         n/a            n/a             NaN
# 18         n/a            n/a             NaN
# 19         n/a            n/a             NaN
# 20         n/a            n/a             NaN
# 21       120.1          111.2             NaN
# 22         n/a            n/a             NaN
# 23       118.4          109.3             NaN
# 24       115.2          105.6             NaN
# 25       120.9            108             NaN
# 26       120.6          110.1             NaN
# 27         n/a            n/a             NaN

# %%
fn = 'Racetrack_data.csv'
df_tracks.to_csv(fn)
print(fn)
# Out:
# Racetrack_data.csv

# %%
track_data
# Out:
# [{'Track': 'CAT - Circuit de Barcelona-Catalunya',
#   'Trk Length': 4.6,
#   'Left_Corners': 6,
#   'Right_Corners': 8,
#   'track_width': 12.0,
#   'length of longest straight': 1047.0,
#   'MotoGP_avg_speed': 164.4,
#   'GP_distance': 111.0,
#   'Moto2_distance': 101.8,
#   'Moto3_distance': 97.2},
#  {'Track': 'JPN - Twin Ring Motegi',
#   'Trk Length': 4.8,
#   'Left_Corners': 6,
#   'Right_Corners': 8,
#   'track_width': 15.0,
#   'length of longest straight': 762.0,
#   'MotoGP_avg_speed': 162.2,
#   'GP_distance': 115.2,
#   'Moto2_distance': 105.6,
#   'Moto3_distance': 96.0},
#  {'Track': 'GER - Sachsenring',
#   'Trk Length': 3.7,
#   'Left_Corners': 10,
#   'Right_Corners': 3,
#   'track_width': 12.0,
#   'length of longest straight': 700.0,
#   'MotoGP_avg_speed': 160.6,
#   'GP_distance': 110.1,
#   'Moto2_distance': 102.8,
#   'Moto3_distance': 99.1},
#  {'Track': 'AME - Circuit Of The Americas',
#   'Trk Length': 5.5,
#   'Left_Corners': 11,
#   'Right_Corners': 9,
#   'track_width': 15.0,
#   'length of longest straight': 1200.0,
#   'MotoGP_avg_speed': 158.4,
#   'GP_distance': 110.3,
#   'Moto2_distance': 99.2,
#   'Moto3_distance': 93.7},
#  {'Track': 'ARA - MotorLand Aragón',
#   'Trk Length': 5.1,
#   'Left_Corners': 10,
#   'Right_Corners': 7,
#   'track_width': 15.0,
#   'length of longest straight': 968.0,
#   'MotoGP_avg_speed': 167.0,
#   'GP_distance': 116.8,
#   'Moto2_distance': 106.6,
#   'Moto3_distance': 96.5},
#  {'Track': 'CZE - Automotodrom Brno',
#   'Trk Length': 5.4,
#   'Left_Corners': 6,
#   'Right_Corners': 8,
#   'track_width': 15.0,
#   'length of longest straight': 636.0,
#   'MotoGP_avg_speed': 165.5,
#   'GP_distance': 113.5,
#   'Moto2_distance': 102.7,
#   'Moto3_distance': 97.3},
#  {'Track': 'NED - TT Circuit Assen',
#   'Trk Length': 4.5,
#   'Left_Corners': 6,
#   'Right_Corners': 12,
#   'track_width': 14.0,
#   'length of longest straight': 487.0,
#   'MotoGP_avg_speed': 173.1,
#   'GP_distance': 118.1,
#   'Moto2_distance': 109.0,
#   'Moto3_distance': 99.9},
#  {'Track': 'VAL - Circuit Ricardo Tormo',
#   'Trk Length': 4.0,
#   'Left_Corners': 9,
#   'Right_Corners': 5,
#   'track_width': 12.0,
#   'length of longest straight': 876.0,
#   'MotoGP_avg_speed': 139.8,
#   'GP_distance': 108.1,
#   'Moto2_distance': 100.1,
#   'Moto3_distance': 92.1},
#  {'Track': 'RSM - Misano World Circuit Marco Simoncelli',
#   'Trk Length': 4.2,
#   'Left_Corners': 6,
#   'Right_Corners': 10,
#   'track_width': 14.0,
#   'length of longest straight': 530.0,
#   'MotoGP_avg_speed': 162.6,
#   'GP_distance': 114.1,
#   'Moto2_distance': 105.7,
#   'Moto3_distance': 97.2},
#  {'Track': 'MAL - Sepang International Circuit',
#   'Trk Length': 5.5,
#   'Left_Corners': 5,
#   'Right_Corners': 10,
#   'track_width': 16.0,
#   'length of longest straight': 920.0,
#   'MotoGP_avg_speed': 164.0,
#   'GP_distance': 110.9,
#   'Moto2_distance': 99.8,
#   'Moto3_distance': 94.2},
#  {'Track': 'QAT - Losail International Circuit',
#   'Trk Length': 5.4,
#   'Left_Corners': 6,
#   'Right_Corners': 10,
#   'track_width': 12.0,
#   'length of longest straight': 1068.0,
#   'MotoGP_avg_speed': 166.6,
#   'GP_distance': 118.4,
#   'Moto2_distance': 107.6,
#   'Moto3_distance': 96.8},
#  {'Track': 'ARG - Termas de Río Hondo',
#   'Trk Length': 4.8,
#   'Left_Corners': 5,
#   'Right_Corners': 9,
#   'track_width': 16.0,
#   'length of longest straight': 1076.0,
#   'MotoGP_avg_speed': 172.7,
#   'GP_distance': 120.2,
#   'Moto2_distance': 110.5,
#   'Moto3_distance': 100.9},
#  {'Track': 'GBR - Silverstone Circuit',
#   'Trk Length': 5.9,
#   'Left_Corners': 8,
#   'Right_Corners': 10,
#   'track_width': 15.0,
#   'length of longest straight': 770.0,
#   'MotoGP_avg_speed': 'n/a',
#   'GP_distance': 118.0,
#   'Moto2_distance': 106.2,
#   'Moto3_distance': 100.3},
#  {'Track': 'FRA - Le Mans',
#   'Trk Length': 4.2,
#   'Left_Corners': 5,
#   'Right_Corners': 9,
#   'track_width': 13.0,
#   'length of longest straight': 674.0,
#   'MotoGP_avg_speed': 161.8,
#   'GP_distance': 113.0,
#   'Moto2_distance': 104.6,
#   'Moto3_distance': 92.1},
#  {'Track': 'SPA - Circuito de Jerez',
#   'Trk Length': 4.4,
#   'Left_Corners': 6,
#   'Right_Corners': 8,
#   'track_width': 11.0,
#   'length of longest straight': 607.0,
#   'MotoGP_avg_speed': 161.2,
#   'GP_distance': 110.6,
#   'Moto2_distance': 101.7,
#   'Moto3_distance': 97.3}]

# %%
pd.read_csv('./Archive/2011_data.csv', index_col=0)
# Out:
#       Year  TRK                                              Track Category  \
# 0     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 1     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 2     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 3     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 4     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 5     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 6     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 7     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 8     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 9     2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 10    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 11    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 12    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 13    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 14    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 15    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...   MotoGP
# 16    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 17    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 18    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 19    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 20    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 21    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 22    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 23    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 24    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 25    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 26    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 27    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 28    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# 29    2011  QAT  Commercialbank Grand Prix of Qatar - Losail In...    Moto2
# ...    ...  ...                                                ...      ...
# 1452  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1453  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1454  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1455  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1456  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1457  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1458  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1459  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1460  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1461  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1462  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1463  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1464  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1465  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1466  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1467  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1468  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1469  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1470  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1471  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1472  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1473  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1474  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1475  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1476  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1477  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1478  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1479  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1480  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
# 1481  2011  VAL  GP Generali de la Comunitat Valenciana - Circu...    125cc
#
#      Session              Date Track_Condition Track_Temp Air_Temp Humidity  \
# 0        RAC     March,20,2011             Dry        20º      19º      31%
# 1        RAC     March,20,2011             Dry        20º      19º      31%
# 2        RAC     March,20,2011             Dry        20º      19º      31%
# 3        RAC     March,20,2011             Dry        20º      19º      31%
# 4        RAC     March,20,2011             Dry        20º      19º      31%
# 5        RAC     March,20,2011             Dry        20º      19º      31%
# 6        RAC     March,20,2011             Dry        20º      19º      31%
# 7        RAC     March,20,2011             Dry        20º      19º      31%
# 8        RAC     March,20,2011             Dry        20º      19º      31%
# 9        RAC     March,20,2011             Dry        20º      19º      31%
# 10       RAC     March,20,2011             Dry        20º      19º      31%
# 11       RAC     March,20,2011             Dry        20º      19º      31%
# 12       RAC     March,20,2011             Dry        20º      19º      31%
# 13       RAC     March,20,2011             Dry        20º      19º      31%
# 14       RAC     March,20,2011             Dry        20º      19º      31%
# 15       RAC     March,20,2011             Dry        20º      19º      31%
# 16       RAC     March,20,2011             Dry        21º      20º      23%
# 17       RAC     March,20,2011             Dry        21º      20º      23%
# 18       RAC     March,20,2011             Dry        21º      20º      23%
# 19       RAC     March,20,2011             Dry        21º      20º      23%
# 20       RAC     March,20,2011             Dry        21º      20º      23%
# 21       RAC     March,20,2011             Dry        21º      20º      23%
# 22       RAC     March,20,2011             Dry        21º      20º      23%
# 23       RAC     March,20,2011             Dry        21º      20º      23%
# 24       RAC     March,20,2011             Dry        21º      20º      23%
# 25       RAC     March,20,2011             Dry        21º      20º      23%
# 26       RAC     March,20,2011             Dry        21º      20º      23%
# 27       RAC     March,20,2011             Dry        21º      20º      23%
# 28       RAC     March,20,2011             Dry        21º      20º      23%
# 29       RAC     March,20,2011             Dry        21º      20º      23%
# ...      ...               ...             ...        ...      ...      ...
# 1452     RAC  November,06,2011             Dry        16º      17º      47%
# 1453     RAC  November,06,2011             Dry        16º      17º      47%
# 1454     RAC  November,06,2011             Dry        16º      17º      47%
# 1455     RAC  November,06,2011             Dry        16º      17º      47%
# 1456     RAC  November,06,2011             Dry        16º      17º      47%
# 1457     RAC  November,06,2011             Dry        16º      17º      47%
# 1458     RAC  November,06,2011             Dry        16º      17º      47%
# 1459     RAC  November,06,2011             Dry        16º      17º      47%
# 1460     RAC  November,06,2011             Dry        16º      17º      47%
# 1461     RAC  November,06,2011             Dry        16º      17º      47%
# 1462     RAC  November,06,2011             Dry        16º      17º      47%
# 1463     RAC  November,06,2011             Dry        16º      17º      47%
# 1464     RAC  November,06,2011             Dry        16º      17º      47%
# 1465     RAC  November,06,2011             Dry        16º      17º      47%
# 1466     RAC  November,06,2011             Dry        16º      17º      47%
# 1467     RAC  November,06,2011             Dry        16º      17º      47%
# 1468     RAC  November,06,2011             Dry        16º      17º      47%
# 1469     RAC  November,06,2011             Dry        16º      17º      47%
# 1470     RAC  November,06,2011             Dry        16º      17º      47%
# 1471     RAC  November,06,2011             Dry        16º      17º      47%
# 1472     RAC  November,06,2011             Dry        16º      17º      47%
# 1473     RAC  November,06,2011             Dry        16º      17º      47%
# 1474     RAC  November,06,2011             Dry        16º      17º      47%
# 1475     RAC  November,06,2011             Dry        16º      17º      47%
# 1476     RAC  November,06,2011             Dry        16º      17º      47%
# 1477     RAC  November,06,2011             Dry        16º      17º      47%
# 1478     RAC  November,06,2011             Dry        16º      17º      47%
# 1479     RAC  November,06,2011             Dry        16º      17º      47%
# 1480     RAC  November,06,2011             Dry        16º      17º      47%
# 1481     RAC  November,06,2011             Dry        16º      17º      47%
#
#      Position  Points  Rider_Number           Rider_Name Nationality  \
# 0           1    25.0          27.0         Casey STONER         AUS
# 1           2    20.0           1.0        Jorge LORENZO         SPA
# 2           3    16.0          26.0         Dani PEDROSA         SPA
# 3           4    13.0           4.0     Andrea DOVIZIOSO         ITA
# 4           5    11.0          58.0     Marco SIMONCELLI         ITA
# 5           6    10.0          11.0            Ben SPIES         USA
# 6           7     9.0          46.0      Valentino ROSSI         ITA
# 7           8     8.0           5.0        Colin EDWARDS         USA
# 8           9     7.0          69.0         Nicky HAYDEN         USA
# 9          10     6.0           7.0       Hiroshi AOYAMA         JPN
# 10         11     5.0          35.0        Cal CRUTCHLOW         GBR
# 11         12     4.0           8.0       Hector BARBERA         SPA
# 12         13     3.0          17.0        Karel ABRAHAM         CZE
# 13      crash     0.0          24.0           Toni ELIAS         SPA
# 14      crash     0.0          65.0      Loris CAPIROSSI         ITA
# 15      crash     0.0          14.0      Randy DE PUNIET         FRA
# 16          1    25.0          65.0         Stefan BRADL         GER
# 17          2    20.0          29.0       Andrea IANNONE         ITA
# 18          3    16.0          12.0         Thomas LUTHI         SWI
# 19          4    13.0          15.0      Alex DE ANGELIS         RSM
# 20          5    11.0          72.0       Yuki TAKAHASHI         JPN
# 21          6    10.0           3.0         Simone CORSI         ITA
# 22          7     9.0          16.0         Jules CLUZEL         FRA
# 23          8     8.0          51.0        Michele PIRRO         ITA
# 24          9     7.0          38.0        Bradley SMITH         GBR
# 25         10     6.0          60.0         Julian SIMON         SPA
# 26         11     5.0          40.0      Aleix ESPARGARO         SPA
# 27         12     4.0          68.0      Yonny HERNANDEZ         COL
# 28         13     3.0          77.0   Dominique AEGERTER         SWI
# 29         14     2.0          34.0         Esteve RABAT         SPA
# ...       ...     ...           ...                  ...         ...
# 1452        5    11.0          94.0         Jonas FOLGER         GER
# 1453        6    10.0          23.0      Alberto MONCAYO         SPA
# 1454        7     9.0          39.0           Luis SALOM         SPA
# 1455        8     8.0          31.0           Niklas AJO         FIN
# 1456        9     7.0           3.0       Luigi MORCIANO         ITA
# 1457       10     6.0          96.0          Louis ROSSI         FRA
# 1458       11     5.0          60.0    Manuel TATASCIORE         ITA
# 1459       12     4.0          77.0     Marcel SCHROTTER         GER
# 1460       13     3.0          19.0   Alessandro TONUCCI         ITA
# 1461       14     2.0          71.0          John McPHEE         GBR
# 1462       15     1.0          30.0       Giulian PEDONE         SWI
# 1463       16     0.0          50.0     Sturla FAGERHAUG         NOR
# 1464       17     0.0          52.0           Danny KENT         GBR
# 1465       18     0.0          56.0      Peter SEBESTYEN         HUN
# 1466       19     0.0          34.0          Daniel RUIZ         SPA
# 1467       20     0.0          53.0         Jasper IWEMA         NED
# 1468       21     0.0          40.0      Marco COLANDREA         SWI
# 1469       22     0.0          10.0        Alexis MASBOU         FRA
# 1470       23     0.0          86.0          Kevin HANUS         GER
# 1471       24     0.0          84.0       Jakub KORNFEIL         CZE
# 1472       25     0.0          63.0  Zulfahmi KHAIRUDDIN         MAL
# 1473    crash     0.0          26.0        Adrian MARTIN         SPA
# 1474    crash     0.0          17.0     Taylor MACKENZIE         GBR
# 1475    crash     0.0          14.0          Brad BINDER         RSA
# 1476    crash     0.0          28.0      Josep RODRIGUEZ         SPA
# 1477    crash     0.0          11.0       Sandro CORTESE         GER
# 1478    crash     0.0          99.0           Danny WEBB         GBR
# 1479    crash     0.0          21.0       Harry STAFFORD         GBR
# 1480    crash     0.0           8.0          Jack MILLER         AUS
# 1481    crash     0.0           5.0         Johann ZARCO         FRA
#
#                            Team_Name        Bike  Avg_Speed       Time
# 0                  Repsol Honda Team       Honda      166.5  42'38.569
# 1              Yamaha Factory Racing      Yamaha      166.3     +3.440
# 2                  Repsol Honda Team       Honda      166.2     +5.051
# 3                  Repsol Honda Team       Honda      166.2     +5.942
# 4            San Carlo Honda Gresini       Honda      166.1     +7.358
# 5              Yamaha Factory Racing      Yamaha      165.9    +10.468
# 6                        Ducati Team      Ducati      165.5    +16.431
# 7              Monster Yamaha Tech 3      Yamaha      164.8    +26.293
# 8                        Ducati Team      Ducati      164.8    +27.416
# 9            San Carlo Honda Gresini       Honda      164.7    +28.920
# 10             Monster Yamaha Tech 3      Yamaha      164.3    +34.539
# 11          Mapfre Aspar Team MotoGP      Ducati      164.3    +34.829
# 12             Cardion AB Motoracing      Ducati      164.1    +37.957
# 13                  LCR Honda MotoGP       Honda      162.8     4 Laps
# 14                Pramac Racing Team      Ducati      142.4    21 Laps
# 15                Pramac Racing Team      Ducati        NaN      0 Lap
# 16           Viessmann Kiefer Racing       Kalex      158.8  40'38.549
# 17                      Speed Master       Suter      158.6     +4.330
# 18         Interwetten Paddock Moto2       Suter      158.5     +5.137
# 19                         JIR Moto2      Motobi      158.5     +5.925
# 20              Gresini Racing Moto2    Moriwaki      158.4     +6.621
# 21               Ioda Racing Project         FTR      157.9    +14.217
# 22                    Forward Racing       Suter      157.9    +14.257
# 23              Gresini Racing Moto2    Moriwaki      157.9    +14.501
# 24                     Tech 3 Racing      Tech 3      157.6    +18.910
# 25           Mapfre Aspar Team Moto2       Suter      157.6    +19.174
# 26                        Pons HP 40  Pons Kalex      157.6    +19.442
# 27                       Blusens-STX         FTR      157.5    +20.830
# 28                     Technomag-CIP       Suter      157.5    +20.837
# 29                       Blusens-STX         FTR      157.5    +20.855
# ...                              ...         ...        ...        ...
# 1452         Red Bull Ajo MotorSport     Aprilia      137.2    +18.451
# 1453          Andalucia Banca Civica     Aprilia      136.2    +36.472
# 1454                    RW Racing GP     Aprilia      135.3    +52.614
# 1455         TT Motion Events Racing     Aprilia      134.9  +1'00.138
# 1456                 Team Italia FMI     Aprilia      134.9  +1'00.253
# 1457                 Matteoni Racing     Aprilia      134.8  +1'03.258
# 1458                  Phonica Racing     Aprilia      134.4  +1'09.892
# 1459                 Mahindra Racing    Mahindra      134.3  +1'12.741
# 1460                 Team Italia FMI     Aprilia      134.0  +1'18.337
# 1461     Racing Steps Foundation KRP     Aprilia      134.0  +1'18.434
# 1462                  Phonica Racing     Aprilia      133.9  +1'20.580
# 1463                WTR-Ten10 Racing     Aprilia      133.8  +1'21.155
# 1464         Red Bull Ajo MotorSport     Aprilia      133.5  +1'27.770
# 1465                 Matteoni Racing     Aprilia      133.2  +1'33.406
# 1466                      Larresport       Honda      133.2  +1'34.593
# 1467           Ongetta-Abbink Metaal     Aprilia      133.1  +1'34.832
# 1468                WTR-Ten10 Racing     Aprilia      131.9      1 Lap
# 1469              Caretta Technology         KTM      131.6      1 Lap
# 1470                    Team Hanusch       Honda      131.3      1 Lap
# 1471             Ongetta-Centro Seta     Aprilia      130.7      1 Lap
# 1472                 Airasia-Sic-Ajo       Derbi      120.1     3 Laps
# 1473         Bankia Aspar Team 125cc     Aprilia      131.0  +2'16.952
# 1474                  Phonica Racing     Aprilia      133.2     6 Laps
# 1475          Andalucia Banca Civica     Aprilia      132.8     7 Laps
# 1476  Blusens by Paris Hilton Racing     Aprilia      116.1     9 Laps
# 1477      Intact-Racing Team Germany     Aprilia      137.1    13 Laps
# 1478                 Mahindra Racing    Mahindra      134.7    13 Laps
# 1479             Ongetta-Centro Seta     Aprilia      128.8    17 Laps
# 1480              Caretta Technology         KTM      130.6    21 Laps
# 1481               Avant-AirAsia-Ajo       Derbi      130.9    22 Laps
#
# [1482 rows x 19 columns]

# %%
import re
new_url = "http://www.motogp.com/en/Results+Statistics/2018/QAT/MotoGP/RAC"
new_soup = soup_stuff(new_url)    

find = new_soup.find(class_='sprite_weather humidity')
if find is None:
    r = 'n/a'
else:
    r = find.findNext().text.split()[1]
    r= re.sub('[%]','',r)
int(r)
# Out:
# 46

# %%
find = new_soup.find(class_='sprite_weather air')
if find is None:
    r = 'n/a'
else:
    r = find.findNext().text.split()[1]
    r= r.strip('º')
float(r)
# Out:
# 21.0
