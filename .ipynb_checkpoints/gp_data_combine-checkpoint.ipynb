# %%
# import dependencies
import time
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import calendar

# %%
rc =pd.read_csv('Racetrack_data.csv', index_col=0)

# %%
rc
# Out:
#                                           Track  Trk Length  Left_Corners  \
# 0          CAT - Circuit de Barcelona-Catalunya      4.6000           6.0
# 1                        JPN - Twin Ring Motegi      4.8000           6.0
# 2                             GER - Sachsenring      3.7000          10.0
# 3                 AME - Circuit Of The Americas      5.5000          11.0
# 4                        ARA - MotorLand Aragón      5.1000          10.0
# 5                       CZE - Automotodrom Brno      5.4000           6.0
# 6                        NED - TT Circuit Assen      4.5000           6.0
# 7                   VAL - Circuit Ricardo Tormo      4.0000           9.0
# 8   RSM - Misano World Circuit Marco Simoncelli      4.2000           6.0
# 9            MAL - Sepang International Circuit      5.5000           5.0
# 10           QAT - Losail International Circuit      5.4000           6.0
# 11                    ARG - Termas de Río Hondo      4.8000           5.0
# 12                    GBR - Silverstone Circuit      5.9000           8.0
# 13                                FRA - Le Mans      4.2000           5.0
# 14                      SPA - Circuito de Jerez      4.4000           6.0
# 15                       CHN - Shanghai Circuit      5.2810           7.0
# 16                 GBR - Donington Park Circuit      4.0230           4.0
# 17            INP - Indianapolis Motor Speedway      4.2160          10.0
# 18                       POR - Estoril Circuitt      4.1820           4.0
# 19                       TUR - Istanbul Circuit      5.3400           8.0
# 20              USA - Mazda Raceway Laguna Seca      3.6100           7.0
# 21                         AUS - Phillip Island      4.4000           7.0
# 22  RIO - Autódromo Internacional Nelson Piquet      5.0310           6.0
# 23            THA - Chang International Circuit      4.6000           5.0
# 24                       PAC - Twin Ring Motegi      4.8000           6.0
# 25                          AUT - Red Bull Ring      4.3000           3.0
# 26   ITA - Autodromo Internazionale del Mugello      5.2000           6.0
# 27                         JPN - Suzuka Circuit      5.8153           7.0
#
#     Right_Corners  track_width  length of longest straight  MotoGP_avg_speed  \
# 0             8.0         12.0                      1047.0             164.4
# 1             8.0         15.0                       762.0             162.2
# 2             3.0         12.0                       700.0             160.6
# 3             9.0         15.0                      1200.0             158.4
# 4             7.0         15.0                       968.0             167.0
# 5             8.0         15.0                       636.0             165.5
# 6            12.0         14.0                       487.0             173.1
# 7             5.0         12.0                       876.0             139.8
# 8            10.0         14.0                       530.0             162.6
# 9            10.0         16.0                       920.0             164.0
# 10           10.0         12.0                      1068.0             166.6
# 11            9.0         16.0                      1076.0             172.7
# 12           10.0         15.0                       770.0               NaN
# 13            9.0         13.0                       674.0             161.8
# 14            8.0         11.0                       607.0             161.2
# 15            7.0         14.0                      1202.0               NaN
# 16            7.0         10.0                       564.0               NaN
# 17            6.0         16.0                       644.0               NaN
# 18            9.0         14.0                       986.0               NaN
# 19            6.0         21.0                       720.0               NaN
# 20            4.0         15.0                       966.0               NaN
# 21            5.0         13.0                       900.0             176.3
# 22            6.0          NaN                         NaN               NaN
# 23            7.0         12.0                      1000.0             177.9
# 24            8.0         15.0                       762.0             162.2
# 25            7.0         13.0                       626.0             182.8
# 26            9.0         14.0                      1141.0             174.1
# 27           10.0          NaN                         NaN               NaN
#
#     GP_distance  Moto2_distance  Moto3_distance
# 0         111.0           101.8            97.2
# 1         115.2           105.6            96.0
# 2         110.1           102.8            99.1
# 3         110.3            99.2            93.7
# 4         116.8           106.6            96.5
# 5         113.5           102.7            97.3
# 6         118.1           109.0            99.9
# 7         108.1           100.1            92.1
# 8         114.1           105.7            97.2
# 9         110.9            99.8            94.2
# 10        118.4           107.6            96.8
# 11        120.2           110.5           100.9
# 12        118.0           106.2           100.3
# 13        113.0           104.6            92.1
# 14        110.6           101.7            97.3
# 15          NaN             NaN             NaN
# 16          NaN             NaN             NaN
# 17          NaN             NaN             NaN
# 18          NaN             NaN             NaN
# 19          NaN             NaN             NaN
# 20          NaN             NaN             NaN
# 21        120.1           111.2             NaN
# 22          NaN             NaN             NaN
# 23        118.4           109.3             NaN
# 24        115.2           105.6             NaN
# 25        120.9           108.0             NaN
# 26        120.6           110.1             NaN
# 27          NaN             NaN             NaN

# %%
years=['2002','2003','2004,''2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017','2018']

def dateparser(dstr):
    d = dict((v,k) for k,v in enumerate(calendar.month_name))
    if type(dstr) != float:
        mon, dd, yyyy = dstr.split(',')
        date_str = '/'.join([str(d[mon]), dd, yyyy])
        return pd.to_datetime(date_str, format='%m/%d/%y')
    else:
        pass
    return None

# function that'll convert finishing time into a proper timedelta value
def timeparser(time_series):
    
    new_time = []
    for index, item in enumerate(time_series):
        prev_case = True
        if pd.isnull(item):
            new_time.append(None)
            continue
        
        if 'Lap' in item:
            new_time.append(None)
            prev_case = False
            
        if ('+' in item) & ("'" not in item):
            t = datetime.strptime(item, "+%S.%f")
            t_delta = timedelta(hours=t.hour, minutes=t.minute,seconds=t.second, microseconds=t.microsecond)
            t_delta = t_delta + base_delta
            new_time.append(t_delta)
            prev_case = False
            
        if ('+' in item) & ("'" in item):
            t = datetime.strptime(item, "+%M'%S.%f")
            t_delta = timedelta(hours=t.hour, minutes=t.minute,seconds=t.second, microseconds=t.microsecond)
            t_delta = t_delta + base_delta
            new_time.append(t_delta)
            prev_case = False
            
        if prev_case:
            base_time = datetime.strptime(item, "%M'%S.%f")
            base_delta = timedelta(hours=base_time.hour, minutes=base_time.minute,
                                   seconds=base_time.second, microseconds=base_time.microsecond)
            new_time.append(base_delta)
            
    return new_time

# function that'll help determine which string values are actually numbers
def isNumber(x):
    if pd.isnull(x):
        return False
    try:
        float(x)
        return True
    except ValueError:
        pass
    return False

def subset(string, chars):
    if pd.isnull(string):
        return None
    else:
        return string[:chars]

# %%
dfs = []
rows_read = []
for yr in reversed(years):
    print(yr, end=', ')
    df = pd.read_csv('./archive/'+yr+'_data.csv', index_col=0, parse_dates=['Date'], date_parser=dateparser)
    df['Track_Temp'] = df['Track_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
    df['Air_Temp'] = df['Air_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
    df['Humidity'] = df['Humidity'].map(lambda x: float(x[:2])/100 if isNumber(subset(x,2)) else x)
    df['Finish_Time'] = timeparser(df.Time)
    df['Track'] = df.TRK.map(lambda x: x+' - ') + df.Track.map(lambda x: x.split(' - ')[1])
    df = df.merge(rc, on='Track', how='left')
    rows_read.append(len(df))
    dfs.append(df)
print('Completed Time Conversion and Merge!!')
# Out:
# 2018,
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     290             try:
# --> 291                 values, tz = conversion.datetime_to_datetime64(arg)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-bdb5ef272c63> in <module>
#       3 for yr in reversed(years):
#       4     print(yr, end=', ')
# ----> 5     df = pd.read_csv('./archive/'+yr+'_data.csv', index_col=0, parse_dates=['Date'], date_parser=dateparser)
#       6     df['Track_Temp'] = df['Track_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
#       7     df['Air_Temp'] = df['Air_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2066             data = {k: v for k, (i, v) in zip(names, data)}
#    2067
# -> 2068             names, data = self._do_date_conversions(names, data)
#    2069             index, names = self._make_index(data, alldata, names)
#    2070
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _do_date_conversions(self, names, data)
#    1818             data, names = _process_date_conversion(
#    1819                 data, self._date_conv, self.parse_dates, self.index_col,
# -> 1820                 self.index_names, names, keep_date_col=self.keep_date_col)
#    1821
#    1822         return names, data
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col)
#    3221                 if _isindex(colspec):
#    3222                     continue
# -> 3223                 data_dict[colspec] = converter(data_dict[colspec])
#    3224             else:
#    3225                 new_name, col, old_names = _try_convert_dates(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3188                         errors='ignore')
#    3189                 except Exception:
# -> 3190                     return generic_parser(date_parser, *date_cols)
#    3191
#    3192     return converter
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\date_converters.py in generic_parser(parse_func, *cols)
#      38     for i in range(N):
#      39         args = [c[i] for c in cols]
# ---> 40         results[i] = parse_func(*args)
#      41
#      42     return results
#
# <ipython-input-11-03b87d2743b4> in dateparser(dstr)
#       6         mon, dd, yyyy = dstr.split(',')
#       7         date_str = '/'.join([str(d[mon]), dd, yyyy])
# ----> 8         return pd.to_datetime(date_str, format='%m/%d/%y')
#       9     else:
#      10         pass
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     609             result = convert_listlike(arg, box, format)
#     610     else:
# --> 611         result = convert_listlike(np.array([arg]), box, format)[0]
#     612
#     613     return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     292                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     293             except (ValueError, TypeError):
# --> 294                 raise e
#     295
#     296     if result is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     259                 try:
#     260                     result, timezones = array_strptime(
# --> 261                         arg, format, exact=exact, errors=errors)
#     262                     if '%Z' in format or '%z' in format:
#     263                         return _return_parsed_timezone_results(
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains: 18
