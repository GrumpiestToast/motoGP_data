# %%
# import dependencies
import time
from pprint import pprint
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import calendar

# %%
rc =pd.read_csv('Racetrack_data.csv', index_col=0)

# %%
years=["2019"]




# function to parse dates as we read in results csv files
def dateparser(dstr):
    """ Returns a datetime object for any date string in the format
        Month, dd, yyyy """
    d = dict((v,k) for k,v in enumerate(calendar.month_name))
    if type(dstr) != float:
        mon, dd, yyyy = dstr.split(',')
        date_str = '/'.join([str(d[mon]), dd, yyyy])
        return pd.to_datetime(date_str, format='%m/%d/%Y')
    else:
        pass
    return None

# function that'll help determine which string values are actually numbers
def isNumber(x):
    if pd.isnull(x):
        return False
    try:
        float(x)
        return True
    except ValueError:
        pass
    return False

def subset(string, chars):
    if pd.isnull(string):
        return None
    else:
        return string[:chars]

# function that'll convert finishing time into a proper timedelta value
def timeparser(time_series):
    
    new_time = []
    for index, item in enumerate(time_series):
        prev_case = True
        if pd.isnull(item):
            new_time.append(None)
            continue
        
        if 'Lap' in item:
            new_time.append(None)
            prev_case = False
            
        if ('+' in item) & ("'" not in item):
            t = datetime.strptime(item, "+%S.%f")
            t_delta = timedelta(hours=t.hour, minutes=t.minute,seconds=t.second, microseconds=t.microsecond)
            t_delta = t_delta + base_delta
            new_time.append(t_delta)
            prev_case = False
            
        if ('+' in item) & ("'" in item):
            t = datetime.strptime(item, "+%M'%S.%f")
            t_delta = timedelta(hours=t.hour, minutes=t.minute,seconds=t.second, microseconds=t.microsecond)
            t_delta = t_delta + base_delta
            new_time.append(t_delta)
            prev_case = False
            
        if prev_case:
            base_time = datetime.strptime(item, "%M'%S.%f")
            base_delta = timedelta(hours=base_time.hour, minutes=base_time.minute,
                                   seconds=base_time.second, microseconds=base_time.microsecond)
            new_time.append(base_delta)
            
    return new_time

# %%
dfs = []
rows_read = []
for yr in reversed(years):
    print(yr, end=', ')
    df = pd.read_csv('./archive/'+yr+'_data.csv', index_col=0, parse_dates=['Date'], date_parser=dateparser)
#     df['Track_Temp'] = df['Track_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
#     df['Air_Temp'] = df['Air_Temp'].map(lambda x: int(x[:2]) if isNumber(subset(x,2)) else x)
#     df['Humidity'] = df['Humidity'].map(lambda x: float(x[:2])/100 if isNumber(subset(x,2)) else x)
    df['Finish_Time'] = timeparser(df.Time)
    df['Track'] = df.TRK.map(lambda x: x+' - ') + df.Track.map(lambda x: x.split(' - ')[1])
    df = df.merge(rc, on='Track', how='left')
    rows_read.append(len(df))
    dfs.append(df)
print('Completed Time Conversion and Merge!!')
# Out:
# 2019, Completed Time Conversion and Merge!!

# %%
result = pd.concat(dfs, ignore_index=True)
fn = 'MotoGP_2019.csv'
result.to_csv(fn)

# %%
pd.read_csv('MotoGP_2019.csv').head(50)
# Out:
#     Unnamed: 0  Year  TRK                               Track Category  \
# 0            0  2019  QAT  QAT - Losail International Circuit   MotoGP
# 1            1  2019  QAT  QAT - Losail International Circuit   MotoGP
# 2            2  2019  QAT  QAT - Losail International Circuit   MotoGP
# 3            3  2019  QAT  QAT - Losail International Circuit   MotoGP
# 4            4  2019  QAT  QAT - Losail International Circuit   MotoGP
# 5            5  2019  QAT  QAT - Losail International Circuit   MotoGP
# 6            6  2019  QAT  QAT - Losail International Circuit   MotoGP
# 7            7  2019  QAT  QAT - Losail International Circuit   MotoGP
# 8            8  2019  QAT  QAT - Losail International Circuit   MotoGP
# 9            9  2019  QAT  QAT - Losail International Circuit   MotoGP
# 10          10  2019  QAT  QAT - Losail International Circuit   MotoGP
# 11          11  2019  QAT  QAT - Losail International Circuit   MotoGP
# 12          12  2019  QAT  QAT - Losail International Circuit   MotoGP
# 13          13  2019  QAT  QAT - Losail International Circuit   MotoGP
# 14          14  2019  QAT  QAT - Losail International Circuit   MotoGP
# 15          15  2019  QAT  QAT - Losail International Circuit   MotoGP
# 16          16  2019  QAT  QAT - Losail International Circuit   MotoGP
# 17          17  2019  QAT  QAT - Losail International Circuit   MotoGP
# 18          18  2019  QAT  QAT - Losail International Circuit   MotoGP
# 19          19  2019  QAT  QAT - Losail International Circuit   MotoGP
# 20          20  2019  QAT  QAT - Losail International Circuit   MotoGP
# 21          21  2019  QAT  QAT - Losail International Circuit   MotoGP
# 22          22  2019  QAT  QAT - Losail International Circuit   MotoGP
# 23          23  2019  QAT  QAT - Losail International Circuit    Moto2
# 24          24  2019  QAT  QAT - Losail International Circuit    Moto2
# 25          25  2019  QAT  QAT - Losail International Circuit    Moto2
# 26          26  2019  QAT  QAT - Losail International Circuit    Moto2
# 27          27  2019  QAT  QAT - Losail International Circuit    Moto2
# 28          28  2019  QAT  QAT - Losail International Circuit    Moto2
# 29          29  2019  QAT  QAT - Losail International Circuit    Moto2
# 30          30  2019  QAT  QAT - Losail International Circuit    Moto2
# 31          31  2019  QAT  QAT - Losail International Circuit    Moto2
# 32          32  2019  QAT  QAT - Losail International Circuit    Moto2
# 33          33  2019  QAT  QAT - Losail International Circuit    Moto2
# 34          34  2019  QAT  QAT - Losail International Circuit    Moto2
# 35          35  2019  QAT  QAT - Losail International Circuit    Moto2
# 36          36  2019  QAT  QAT - Losail International Circuit    Moto2
# 37          37  2019  QAT  QAT - Losail International Circuit    Moto2
# 38          38  2019  QAT  QAT - Losail International Circuit    Moto2
# 39          39  2019  QAT  QAT - Losail International Circuit    Moto2
# 40          40  2019  QAT  QAT - Losail International Circuit    Moto2
# 41          41  2019  QAT  QAT - Losail International Circuit    Moto2
# 42          42  2019  QAT  QAT - Losail International Circuit    Moto2
# 43          43  2019  QAT  QAT - Losail International Circuit    Moto2
# 44          44  2019  QAT  QAT - Losail International Circuit    Moto2
# 45          45  2019  QAT  QAT - Losail International Circuit    Moto2
# 46          46  2019  QAT  QAT - Losail International Circuit    Moto2
# 47          47  2019  QAT  QAT - Losail International Circuit    Moto2
# 48          48  2019  QAT  QAT - Losail International Circuit    Moto2
# 49          49  2019  QAT  QAT - Losail International Circuit    Moto2
#
#    Session        Date Track_Condition  Track_Temp  Air_Temp  ...  \
# 0      RAC  2019-03-10             Dry        19.0      18.0  ...
# 1      RAC  2019-03-10             Dry        19.0      18.0  ...
# 2      RAC  2019-03-10             Dry        19.0      18.0  ...
# 3      RAC  2019-03-10             Dry        19.0      18.0  ...
# 4      RAC  2019-03-10             Dry        19.0      18.0  ...
# 5      RAC  2019-03-10             Dry        19.0      18.0  ...
# 6      RAC  2019-03-10             Dry        19.0      18.0  ...
# 7      RAC  2019-03-10             Dry        19.0      18.0  ...
# 8      RAC  2019-03-10             Dry        19.0      18.0  ...
# 9      RAC  2019-03-10             Dry        19.0      18.0  ...
# 10     RAC  2019-03-10             Dry        19.0      18.0  ...
# 11     RAC  2019-03-10             Dry        19.0      18.0  ...
# 12     RAC  2019-03-10             Dry        19.0      18.0  ...
# 13     RAC  2019-03-10             Dry        19.0      18.0  ...
# 14     RAC  2019-03-10             Dry        19.0      18.0  ...
# 15     RAC  2019-03-10             Dry        19.0      18.0  ...
# 16     RAC  2019-03-10             Dry        19.0      18.0  ...
# 17     RAC  2019-03-10             Dry        19.0      18.0  ...
# 18     RAC  2019-03-10             Dry        19.0      18.0  ...
# 19     RAC  2019-03-10             Dry        19.0      18.0  ...
# 20     RAC  2019-03-10             Dry        19.0      18.0  ...
# 21     RAC  2019-03-10             Dry        19.0      18.0  ...
# 22     RAC  2019-03-10             Dry        19.0      18.0  ...
# 23     RAC  2019-03-10             Dry        21.0      20.0  ...
# 24     RAC  2019-03-10             Dry        21.0      20.0  ...
# 25     RAC  2019-03-10             Dry        21.0      20.0  ...
# 26     RAC  2019-03-10             Dry        21.0      20.0  ...
# 27     RAC  2019-03-10             Dry        21.0      20.0  ...
# 28     RAC  2019-03-10             Dry        21.0      20.0  ...
# 29     RAC  2019-03-10             Dry        21.0      20.0  ...
# 30     RAC  2019-03-10             Dry        21.0      20.0  ...
# 31     RAC  2019-03-10             Dry        21.0      20.0  ...
# 32     RAC  2019-03-10             Dry        21.0      20.0  ...
# 33     RAC  2019-03-10             Dry        21.0      20.0  ...
# 34     RAC  2019-03-10             Dry        21.0      20.0  ...
# 35     RAC  2019-03-10             Dry        21.0      20.0  ...
# 36     RAC  2019-03-10             Dry        21.0      20.0  ...
# 37     RAC  2019-03-10             Dry        21.0      20.0  ...
# 38     RAC  2019-03-10             Dry        21.0      20.0  ...
# 39     RAC  2019-03-10             Dry        21.0      20.0  ...
# 40     RAC  2019-03-10             Dry        21.0      20.0  ...
# 41     RAC  2019-03-10             Dry        21.0      20.0  ...
# 42     RAC  2019-03-10             Dry        21.0      20.0  ...
# 43     RAC  2019-03-10             Dry        21.0      20.0  ...
# 44     RAC  2019-03-10             Dry        21.0      20.0  ...
# 45     RAC  2019-03-10             Dry        21.0      20.0  ...
# 46     RAC  2019-03-10             Dry        21.0      20.0  ...
# 47     RAC  2019-03-10             Dry        21.0      20.0  ...
# 48     RAC  2019-03-10             Dry        21.0      20.0  ...
# 49     RAC  2019-03-10             Dry        21.0      20.0  ...
#
#                   Finish_Time Trk Length  Left_Corners  Right_Corners  \
# 0   0 days 00:42:36.902000000        5.4           6.0           10.0
# 1   0 days 00:42:36.925000000        5.4           6.0           10.0
# 2   0 days 00:42:37.222000000        5.4           6.0           10.0
# 3   0 days 00:42:37.359000000        5.4           6.0           10.0
# 4   0 days 00:42:37.502000000        5.4           6.0           10.0
# 5   0 days 00:42:39.222000000        5.4           6.0           10.0
# 6   0 days 00:42:39.383000000        5.4           6.0           10.0
# 7   0 days 00:42:41.990000000        5.4           6.0           10.0
# 8   0 days 00:42:44.308000000        5.4           6.0           10.0
# 9   0 days 00:42:46.538000000        5.4           6.0           10.0
# 10  0 days 00:42:46.549000000        5.4           6.0           10.0
# 11  0 days 00:42:49.676000000        5.4           6.0           10.0
# 12  0 days 00:42:51.209000000        5.4           6.0           10.0
# 13  0 days 00:42:51.251000000        5.4           6.0           10.0
# 14  0 days 00:42:51.995000000        5.4           6.0           10.0
# 15  0 days 00:42:52.807000000        5.4           6.0           10.0
# 16  0 days 00:42:53.279000000        5.4           6.0           10.0
# 17  0 days 00:42:59.874000000        5.4           6.0           10.0
# 18  0 days 00:42:59.941000000        5.4           6.0           10.0
# 19  0 days 00:43:20.144000000        5.4           6.0           10.0
# 20                        NaN        5.4           6.0           10.0
# 21                        NaN        5.4           6.0           10.0
# 22                        NaN        5.4           6.0           10.0
# 23  0 days 00:39:56.109000000        5.4           6.0           10.0
# 24  0 days 00:39:56.135000000        5.4           6.0           10.0
# 25  0 days 00:39:58.232000000        5.4           6.0           10.0
# 26  0 days 00:39:58.234000000        5.4           6.0           10.0
# 27  0 days 00:39:58.414000000        5.4           6.0           10.0
# 28  0 days 00:39:59.443000000        5.4           6.0           10.0
# 29  0 days 00:40:01.127000000        5.4           6.0           10.0
# 30  0 days 00:40:03.445000000        5.4           6.0           10.0
# 31  0 days 00:40:09.058000000        5.4           6.0           10.0
# 32  0 days 00:40:09.974000000        5.4           6.0           10.0
# 33  0 days 00:40:11.634000000        5.4           6.0           10.0
# 34  0 days 00:40:12.700000000        5.4           6.0           10.0
# 35  0 days 00:40:14.776000000        5.4           6.0           10.0
# 36  0 days 00:40:15.025000000        5.4           6.0           10.0
# 37  0 days 00:40:18.880000000        5.4           6.0           10.0
# 38  0 days 00:40:18.931000000        5.4           6.0           10.0
# 39  0 days 00:40:20.087000000        5.4           6.0           10.0
# 40  0 days 00:40:23.013000000        5.4           6.0           10.0
# 41  0 days 00:40:23.139000000        5.4           6.0           10.0
# 42  0 days 00:40:36.383000000        5.4           6.0           10.0
# 43  0 days 00:40:39.112000000        5.4           6.0           10.0
# 44  0 days 00:40:40.321000000        5.4           6.0           10.0
# 45  0 days 00:40:43.766000000        5.4           6.0           10.0
# 46  0 days 00:40:53.705000000        5.4           6.0           10.0
# 47  0 days 00:41:14.858000000        5.4           6.0           10.0
# 48  0 days 00:41:31.926000000        5.4           6.0           10.0
# 49                        NaN        5.4           6.0           10.0
#
#    track_width length of longest straight MotoGP_avg_speed GP_distance  \
# 0         12.0                     1068.0            166.6       118.4
# 1         12.0                     1068.0            166.6       118.4
# 2         12.0                     1068.0            166.6       118.4
# 3         12.0                     1068.0            166.6       118.4
# 4         12.0                     1068.0            166.6       118.4
# 5         12.0                     1068.0            166.6       118.4
# 6         12.0                     1068.0            166.6       118.4
# 7         12.0                     1068.0            166.6       118.4
# 8         12.0                     1068.0            166.6       118.4
# 9         12.0                     1068.0            166.6       118.4
# 10        12.0                     1068.0            166.6       118.4
# 11        12.0                     1068.0            166.6       118.4
# 12        12.0                     1068.0            166.6       118.4
# 13        12.0                     1068.0            166.6       118.4
# 14        12.0                     1068.0            166.6       118.4
# 15        12.0                     1068.0            166.6       118.4
# 16        12.0                     1068.0            166.6       118.4
# 17        12.0                     1068.0            166.6       118.4
# 18        12.0                     1068.0            166.6       118.4
# 19        12.0                     1068.0            166.6       118.4
# 20        12.0                     1068.0            166.6       118.4
# 21        12.0                     1068.0            166.6       118.4
# 22        12.0                     1068.0            166.6       118.4
# 23        12.0                     1068.0            166.6       118.4
# 24        12.0                     1068.0            166.6       118.4
# 25        12.0                     1068.0            166.6       118.4
# 26        12.0                     1068.0            166.6       118.4
# 27        12.0                     1068.0            166.6       118.4
# 28        12.0                     1068.0            166.6       118.4
# 29        12.0                     1068.0            166.6       118.4
# 30        12.0                     1068.0            166.6       118.4
# 31        12.0                     1068.0            166.6       118.4
# 32        12.0                     1068.0            166.6       118.4
# 33        12.0                     1068.0            166.6       118.4
# 34        12.0                     1068.0            166.6       118.4
# 35        12.0                     1068.0            166.6       118.4
# 36        12.0                     1068.0            166.6       118.4
# 37        12.0                     1068.0            166.6       118.4
# 38        12.0                     1068.0            166.6       118.4
# 39        12.0                     1068.0            166.6       118.4
# 40        12.0                     1068.0            166.6       118.4
# 41        12.0                     1068.0            166.6       118.4
# 42        12.0                     1068.0            166.6       118.4
# 43        12.0                     1068.0            166.6       118.4
# 44        12.0                     1068.0            166.6       118.4
# 45        12.0                     1068.0            166.6       118.4
# 46        12.0                     1068.0            166.6       118.4
# 47        12.0                     1068.0            166.6       118.4
# 48        12.0                     1068.0            166.6       118.4
# 49        12.0                     1068.0            166.6       118.4
#
#     Moto2_distance Moto3_distance
# 0            107.6           96.8
# 1            107.6           96.8
# 2            107.6           96.8
# 3            107.6           96.8
# 4            107.6           96.8
# 5            107.6           96.8
# 6            107.6           96.8
# 7            107.6           96.8
# 8            107.6           96.8
# 9            107.6           96.8
# 10           107.6           96.8
# 11           107.6           96.8
# 12           107.6           96.8
# 13           107.6           96.8
# 14           107.6           96.8
# 15           107.6           96.8
# 16           107.6           96.8
# 17           107.6           96.8
# 18           107.6           96.8
# 19           107.6           96.8
# 20           107.6           96.8
# 21           107.6           96.8
# 22           107.6           96.8
# 23           107.6           96.8
# 24           107.6           96.8
# 25           107.6           96.8
# 26           107.6           96.8
# 27           107.6           96.8
# 28           107.6           96.8
# 29           107.6           96.8
# 30           107.6           96.8
# 31           107.6           96.8
# 32           107.6           96.8
# 33           107.6           96.8
# 34           107.6           96.8
# 35           107.6           96.8
# 36           107.6           96.8
# 37           107.6           96.8
# 38           107.6           96.8
# 39           107.6           96.8
# 40           107.6           96.8
# 41           107.6           96.8
# 42           107.6           96.8
# 43           107.6           96.8
# 44           107.6           96.8
# 45           107.6           96.8
# 46           107.6           96.8
# 47           107.6           96.8
# 48           107.6           96.8
# 49           107.6           96.8
#
# [50 rows x 30 columns]
