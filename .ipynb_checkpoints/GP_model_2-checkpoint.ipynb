# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from sklearn.linear_model import LinearRegression, Lasso, Ridge
import statsmodels.api as sm
import statsmodels.formula.api as smf 
import scipy.stats as stats

# %%
df_orig = pd.read_csv('MotoGP_2002_2018.csv', index_col=0, parse_dates=['Date'])

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24141 entries, 0 to 24140
# Data columns (total 29 columns):
# Year                          24141 non-null int64
# TRK                           24141 non-null object
# Track                         24141 non-null object
# Category                      24141 non-null object
# Session                       24141 non-null object
# Date                          24136 non-null datetime64[ns]
# Track_Condition               20883 non-null object
# Track_Temp                    20883 non-null float64
# Air_Temp                      20883 non-null float64
# Humidity                      20883 non-null float64
# Position                      24136 non-null object
# Points                        24136 non-null float64
# Rider_Number                  20883 non-null float64
# Rider_Name                    24136 non-null object
# Nationality                   24136 non-null object
# Team_Name                     20883 non-null object
# Bike                          24136 non-null object
# Avg_Speed                     23310 non-null float64
# Time                          24135 non-null object
# Finish_Time                   18577 non-null object
# Trk Length                    22880 non-null float64
# Left_Corners                  22880 non-null float64
# Right_Corners                 22880 non-null float64
# track_width                   22760 non-null float64
# length of longest straight    22760 non-null float64
# MotoGP_avg_speed              20008 non-null float64
# GP_distance                   20708 non-null float64
# Moto2_distance                20708 non-null float64
# Moto3_distance                17439 non-null float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(12)
# memory usage: 5.5+ MB

# %%
df = df_orig.copy(deep=True)

# %%
# convert finish time into a numerical since it'll be the target of our regression
df['Finish_Time'] = df['Finish_Time'].map(lambda x: pd.to_timedelta(x))
df['Finish_Time_ms'] = df['Finish_Time'].map(lambda x: x/pd.to_timedelta(1, unit='ms'))

# add up left and right corners
df['corners'] = df['Left_Corners'] + df['Right_Corners']

# drop N/A values
df.dropna(axis = 0, inplace=True)

# %%
# examine the top 20 riders
(df
 .groupby(['Rider_Name'])['Points']
 .mean().reset_index()
 .sort_values(by='Points', ascending=False)
).head(20)
# Out:
#            Rider_Name     Points
# 66           Can ONCU  25.000000
# 86     Daniel PEDROSA  22.555556
# 282      Marc MARQUEZ  19.358974
# 69       Casey STONER  17.742857
# 206     Jorge LORENZO  17.375000
# 439   Valentino ROSSI  16.077419
# 82       Dani PEDROSA  15.985507
# 300  Maverick VIÑALES  13.833333
# 23          Alex RINS  13.500000
# 191          Joan MIR  13.472222
# 33   Andrea DOVIZIOSO  13.006623
# 288  Marco SIMONCELLI  12.068966
# 45         Aron CANET  11.961538
# 207      Jorge MARTIN  11.777778
# 111   Enea BASTIANINI  11.655172
# 22       Alex MARQUEZ  11.633803
# 142    Gabor TALMACSI  11.450000
# 316       Mika KALLIO  11.449541
# 384   Sebastian PORTO  11.444444
# 423      Thomas LUTHI  11.433566

# %%
df.replace(to_replace='Daniel PEDROSA', value='Dani PEDROSA', inplace=True)
df_rider_mean = (df
                 .groupby(['Rider_Name'])['Points']
                 .mean().reset_index()
                 .sort_values(by='Points', ascending=False)
                )
df_rider_mean.rename(columns={'Points':'points_mean'}, inplace=True)
df_rider_mean.head(20)
# Out:
#            Rider_Name  points_mean
# 66           Can ONCU    25.000000
# 281      Marc MARQUEZ    19.358974
# 69       Casey STONER    17.742857
# 205     Jorge LORENZO    17.375000
# 82       Dani PEDROSA    16.387755
# 438   Valentino ROSSI    16.077419
# 299  Maverick VIÑALES    13.833333
# 23          Alex RINS    13.500000
# 190          Joan MIR    13.472222
# 33   Andrea DOVIZIOSO    13.006623
# 287  Marco SIMONCELLI    12.068966
# 45         Aron CANET    11.961538
# 206      Jorge MARTIN    11.777778
# 110   Enea BASTIANINI    11.655172
# 22       Alex MARQUEZ    11.633803
# 141    Gabor TALMACSI    11.450000
# 315       Mika KALLIO    11.449541
# 383   Sebastian PORTO    11.444444
# 422      Thomas LUTHI    11.433566
# 314   Miguel OLIVEIRA    11.428571

# %%
df.groupby('Rider_Name').count()
# Out:
#                       Year  TRK  Track  Category  Session  Date  \
# Rider_Name
# Aaron POLANCO            1    1      1         1        1     1
# Adam NORRODIN           27   27     27        27       27    27
# Adrian MARTIN           24   24     24        24       24    24
# Ai OGURA                 2    2      2         2        2     2
# Aitor RODRIGUEZ          2    2      2         2        2     2
# Alan TECHER             17   17     17        17       17    17
# Albert ARENAS           20   20     20        20       20    20
# Alberto MONCAYO         43   43     43        43       43    43
# Aleix ESPARGARO        124  124    124       124      124   124
# Aleix VIU                1    1      1         1        1     1
# Alen GYORFI              1    1      1         1        1     1
# Alessandro ANDREOZZI     7    7      7         7        7     7
# Alessandro BRANNETTI     1    1      1         1        1     1
# Alessandro GIORGI        1    1      1         1        1     1
# Alessandro TONUCCI      58   58     58        58       58    58
# Alessio PALUMBO          1    1      1         1        1     1
# Alex BALDOLINI          48   48     48        48       48    48
# Alex BARROS             16   16     16        16       16    16
# Alex DE ANGELIS         97   97     97        97       97    97
# Alex DEBON              39   39     39        39       39    39
# Alex HOFMANN            16   16     16        16       16    16
# Alex MARIÑELARENA        3    3      3         3        3     3
# Alex MARQUEZ            71   71     71        71       71    71
# Alex RINS               78   78     78        78       78    78
# Alexander CUDLIN         1    1      1         1        1     1
# Alexander LUNDH          3    3      3         3        3     3
# Alexis MASBOU           80   80     80        80       80    80
# Alonso LOPEZ             9    9      9         9        9     9
# Alvaro BAUTISTA        136  136    136       136      136   136
# Alvaro MOLINA            4    4      4         4        4     4
# ...                    ...  ...    ...       ...      ...   ...
# Tom TOPARIS              1    1      1         1        1     1
# Tommaso GABRIELLI        2    2      2         2        2     2
# Tomoyoshi KOYAMA        61   61     61        61       61    61
# Toni ELIAS              75   75     75        75       75    75
# Toni FINSTERBUSCH       17   17     17        17       17    17
# Toni WIRSING             3    3      3         3        3     3
# Tony ARBOLINO           22   22     22        22       22    22
# Toshihisa KUZUHARA       4    4      4         4        4     4
# Troy BAYLISS             5    5      5         5        5     5
# Valentin DEBISE         25   25     25        25       25    25
# Valentino ROSSI        155  155    155       155      155   155
# Vicente PEREZ            5    5      5         5        5     5
# Vincent BRAILLARD       12   12     12        12       12    12
# Vladimir IVANOV          9    9      9         9        9     9
# Vladimir LEONOV          7    7      7         7        7     7
# Wai On CHEUNG            1    1      1         1        1     1
# Wataru YOSHIKAWA         1    1      1         1        1     1
# Xavi CARDELUS            6    6      6         6        6     6
# Xavi VIERGE             34   34     34        34       34    34
# Xavier SIMEON           81   81     81        81       81    81
# Yannick GUERRA           8    8      8         8        8     8
# Yari MONTELLA            1    1      1         1        1     1
# Yonny HERNANDEZ         64   64     64        64       64    64
# Youichi UI               2    2      2         2        2     2
# Yuki HAMAMOTO            1    1      1         1        1     1
# Yuki TAKAHASHI          70   70     70        70       70    70
# Yusuke TESHIMA           2    2      2         2        2     2
# Yuuichi YANAGISAWA       2    2      2         2        2     2
# Zaqhwan ZAIDI            4    4      4         4        4     4
# Zulfahmi KHAIRUDDIN     60   60     60        60       60    60
#
#                       Track_Condition  Track_Temp  Air_Temp  Humidity  ...  \
# Rider_Name                                                             ...
# Aaron POLANCO                       1           1         1         1  ...
# Adam NORRODIN                      27          27        27        27  ...
# Adrian MARTIN                      24          24        24        24  ...
# Ai OGURA                            2           2         2         2  ...
# Aitor RODRIGUEZ                     2           2         2         2  ...
# Alan TECHER                        17          17        17        17  ...
# Albert ARENAS                      20          20        20        20  ...
# Alberto MONCAYO                    43          43        43        43  ...
# Aleix ESPARGARO                   124         124       124       124  ...
# Aleix VIU                           1           1         1         1  ...
# Alen GYORFI                         1           1         1         1  ...
# Alessandro ANDREOZZI                7           7         7         7  ...
# Alessandro BRANNETTI                1           1         1         1  ...
# Alessandro GIORGI                   1           1         1         1  ...
# Alessandro TONUCCI                 58          58        58        58  ...
# Alessio PALUMBO                     1           1         1         1  ...
# Alex BALDOLINI                     48          48        48        48  ...
# Alex BARROS                        16          16        16        16  ...
# Alex DE ANGELIS                    97          97        97        97  ...
# Alex DEBON                         39          39        39        39  ...
# Alex HOFMANN                       16          16        16        16  ...
# Alex MARIÑELARENA                   3           3         3         3  ...
# Alex MARQUEZ                       71          71        71        71  ...
# Alex RINS                          78          78        78        78  ...
# Alexander CUDLIN                    1           1         1         1  ...
# Alexander LUNDH                     3           3         3         3  ...
# Alexis MASBOU                      80          80        80        80  ...
# Alonso LOPEZ                        9           9         9         9  ...
# Alvaro BAUTISTA                   136         136       136       136  ...
# Alvaro MOLINA                       4           4         4         4  ...
# ...                               ...         ...       ...       ...  ...
# Tom TOPARIS                         1           1         1         1  ...
# Tommaso GABRIELLI                   2           2         2         2  ...
# Tomoyoshi KOYAMA                   61          61        61        61  ...
# Toni ELIAS                         75          75        75        75  ...
# Toni FINSTERBUSCH                  17          17        17        17  ...
# Toni WIRSING                        3           3         3         3  ...
# Tony ARBOLINO                      22          22        22        22  ...
# Toshihisa KUZUHARA                  4           4         4         4  ...
# Troy BAYLISS                        5           5         5         5  ...
# Valentin DEBISE                    25          25        25        25  ...
# Valentino ROSSI                   155         155       155       155  ...
# Vicente PEREZ                       5           5         5         5  ...
# Vincent BRAILLARD                  12          12        12        12  ...
# Vladimir IVANOV                     9           9         9         9  ...
# Vladimir LEONOV                     7           7         7         7  ...
# Wai On CHEUNG                       1           1         1         1  ...
# Wataru YOSHIKAWA                    1           1         1         1  ...
# Xavi CARDELUS                       6           6         6         6  ...
# Xavi VIERGE                        34          34        34        34  ...
# Xavier SIMEON                      81          81        81        81  ...
# Yannick GUERRA                      8           8         8         8  ...
# Yari MONTELLA                       1           1         1         1  ...
# Yonny HERNANDEZ                    64          64        64        64  ...
# Youichi UI                          2           2         2         2  ...
# Yuki HAMAMOTO                       1           1         1         1  ...
# Yuki TAKAHASHI                     70          70        70        70  ...
# Yusuke TESHIMA                      2           2         2         2  ...
# Yuuichi YANAGISAWA                  2           2         2         2  ...
# Zaqhwan ZAIDI                       4           4         4         4  ...
# Zulfahmi KHAIRUDDIN                60          60        60        60  ...
#
#                       Left_Corners  Right_Corners  track_width  \
# Rider_Name
# Aaron POLANCO                    1              1            1
# Adam NORRODIN                   27             27           27
# Adrian MARTIN                   24             24           24
# Ai OGURA                         2              2            2
# Aitor RODRIGUEZ                  2              2            2
# Alan TECHER                     17             17           17
# Albert ARENAS                   20             20           20
# Alberto MONCAYO                 43             43           43
# Aleix ESPARGARO                124            124          124
# Aleix VIU                        1              1            1
# Alen GYORFI                      1              1            1
# Alessandro ANDREOZZI             7              7            7
# Alessandro BRANNETTI             1              1            1
# Alessandro GIORGI                1              1            1
# Alessandro TONUCCI              58             58           58
# Alessio PALUMBO                  1              1            1
# Alex BALDOLINI                  48             48           48
# Alex BARROS                     16             16           16
# Alex DE ANGELIS                 97             97           97
# Alex DEBON                      39             39           39
# Alex HOFMANN                    16             16           16
# Alex MARIÑELARENA                3              3            3
# Alex MARQUEZ                    71             71           71
# Alex RINS                       78             78           78
# Alexander CUDLIN                 1              1            1
# Alexander LUNDH                  3              3            3
# Alexis MASBOU                   80             80           80
# Alonso LOPEZ                     9              9            9
# Alvaro BAUTISTA                136            136          136
# Alvaro MOLINA                    4              4            4
# ...                            ...            ...          ...
# Tom TOPARIS                      1              1            1
# Tommaso GABRIELLI                2              2            2
# Tomoyoshi KOYAMA                61             61           61
# Toni ELIAS                      75             75           75
# Toni FINSTERBUSCH               17             17           17
# Toni WIRSING                     3              3            3
# Tony ARBOLINO                   22             22           22
# Toshihisa KUZUHARA               4              4            4
# Troy BAYLISS                     5              5            5
# Valentin DEBISE                 25             25           25
# Valentino ROSSI                155            155          155
# Vicente PEREZ                    5              5            5
# Vincent BRAILLARD               12             12           12
# Vladimir IVANOV                  9              9            9
# Vladimir LEONOV                  7              7            7
# Wai On CHEUNG                    1              1            1
# Wataru YOSHIKAWA                 1              1            1
# Xavi CARDELUS                    6              6            6
# Xavi VIERGE                     34             34           34
# Xavier SIMEON                   81             81           81
# Yannick GUERRA                   8              8            8
# Yari MONTELLA                    1              1            1
# Yonny HERNANDEZ                 64             64           64
# Youichi UI                       2              2            2
# Yuki HAMAMOTO                    1              1            1
# Yuki TAKAHASHI                  70             70           70
# Yusuke TESHIMA                   2              2            2
# Yuuichi YANAGISAWA               2              2            2
# Zaqhwan ZAIDI                    4              4            4
# Zulfahmi KHAIRUDDIN             60             60           60
#
#                       length of longest straight  MotoGP_avg_speed  \
# Rider_Name
# Aaron POLANCO                                  1                 1
# Adam NORRODIN                                 27                27
# Adrian MARTIN                                 24                24
# Ai OGURA                                       2                 2
# Aitor RODRIGUEZ                                2                 2
# Alan TECHER                                   17                17
# Albert ARENAS                                 20                20
# Alberto MONCAYO                               43                43
# Aleix ESPARGARO                              124               124
# Aleix VIU                                      1                 1
# Alen GYORFI                                    1                 1
# Alessandro ANDREOZZI                           7                 7
# Alessandro BRANNETTI                           1                 1
# Alessandro GIORGI                              1                 1
# Alessandro TONUCCI                            58                58
# Alessio PALUMBO                                1                 1
# Alex BALDOLINI                                48                48
# Alex BARROS                                   16                16
# Alex DE ANGELIS                               97                97
# Alex DEBON                                    39                39
# Alex HOFMANN                                  16                16
# Alex MARIÑELARENA                              3                 3
# Alex MARQUEZ                                  71                71
# Alex RINS                                     78                78
# Alexander CUDLIN                               1                 1
# Alexander LUNDH                                3                 3
# Alexis MASBOU                                 80                80
# Alonso LOPEZ                                   9                 9
# Alvaro BAUTISTA                              136               136
# Alvaro MOLINA                                  4                 4
# ...                                          ...               ...
# Tom TOPARIS                                    1                 1
# Tommaso GABRIELLI                              2                 2
# Tomoyoshi KOYAMA                              61                61
# Toni ELIAS                                    75                75
# Toni FINSTERBUSCH                             17                17
# Toni WIRSING                                   3                 3
# Tony ARBOLINO                                 22                22
# Toshihisa KUZUHARA                             4                 4
# Troy BAYLISS                                   5                 5
# Valentin DEBISE                               25                25
# Valentino ROSSI                              155               155
# Vicente PEREZ                                  5                 5
# Vincent BRAILLARD                             12                12
# Vladimir IVANOV                                9                 9
# Vladimir LEONOV                                7                 7
# Wai On CHEUNG                                  1                 1
# Wataru YOSHIKAWA                               1                 1
# Xavi CARDELUS                                  6                 6
# Xavi VIERGE                                   34                34
# Xavier SIMEON                                 81                81
# Yannick GUERRA                                 8                 8
# Yari MONTELLA                                  1                 1
# Yonny HERNANDEZ                               64                64
# Youichi UI                                     2                 2
# Yuki HAMAMOTO                                  1                 1
# Yuki TAKAHASHI                                70                70
# Yusuke TESHIMA                                 2                 2
# Yuuichi YANAGISAWA                             2                 2
# Zaqhwan ZAIDI                                  4                 4
# Zulfahmi KHAIRUDDIN                           60                60
#
#                       GP_distance  Moto2_distance  Moto3_distance  \
# Rider_Name
# Aaron POLANCO                   1               1               1
# Adam NORRODIN                  27              27              27
# Adrian MARTIN                  24              24              24
# Ai OGURA                        2               2               2
# Aitor RODRIGUEZ                 2               2               2
# Alan TECHER                    17              17              17
# Albert ARENAS                  20              20              20
# Alberto MONCAYO                43              43              43
# Aleix ESPARGARO               124             124             124
# Aleix VIU                       1               1               1
# Alen GYORFI                     1               1               1
# Alessandro ANDREOZZI            7               7               7
# Alessandro BRANNETTI            1               1               1
# Alessandro GIORGI               1               1               1
# Alessandro TONUCCI             58              58              58
# Alessio PALUMBO                 1               1               1
# Alex BALDOLINI                 48              48              48
# Alex BARROS                    16              16              16
# Alex DE ANGELIS                97              97              97
# Alex DEBON                     39              39              39
# Alex HOFMANN                   16              16              16
# Alex MARIÑELARENA               3               3               3
# Alex MARQUEZ                   71              71              71
# Alex RINS                      78              78              78
# Alexander CUDLIN                1               1               1
# Alexander LUNDH                 3               3               3
# Alexis MASBOU                  80              80              80
# Alonso LOPEZ                    9               9               9
# Alvaro BAUTISTA               136             136             136
# Alvaro MOLINA                   4               4               4
# ...                           ...             ...             ...
# Tom TOPARIS                     1               1               1
# Tommaso GABRIELLI               2               2               2
# Tomoyoshi KOYAMA               61              61              61
# Toni ELIAS                     75              75              75
# Toni FINSTERBUSCH              17              17              17
# Toni WIRSING                    3               3               3
# Tony ARBOLINO                  22              22              22
# Toshihisa KUZUHARA              4               4               4
# Troy BAYLISS                    5               5               5
# Valentin DEBISE                25              25              25
# Valentino ROSSI               155             155             155
# Vicente PEREZ                   5               5               5
# Vincent BRAILLARD              12              12              12
# Vladimir IVANOV                 9               9               9
# Vladimir LEONOV                 7               7               7
# Wai On CHEUNG                   1               1               1
# Wataru YOSHIKAWA                1               1               1
# Xavi CARDELUS                   6               6               6
# Xavi VIERGE                    34              34              34
# Xavier SIMEON                  81              81              81
# Yannick GUERRA                  8               8               8
# Yari MONTELLA                   1               1               1
# Yonny HERNANDEZ                64              64              64
# Youichi UI                      2               2               2
# Yuki HAMAMOTO                   1               1               1
# Yuki TAKAHASHI                 70              70              70
# Yusuke TESHIMA                  2               2               2
# Yuuichi YANAGISAWA              2               2               2
# Zaqhwan ZAIDI                   4               4               4
# Zulfahmi KHAIRUDDIN            60              60              60
#
#                       Finish_Time_ms  corners
# Rider_Name
# Aaron POLANCO                      1        1
# Adam NORRODIN                     27       27
# Adrian MARTIN                     24       24
# Ai OGURA                           2        2
# Aitor RODRIGUEZ                    2        2
# Alan TECHER                       17       17
# Albert ARENAS                     20       20
# Alberto MONCAYO                   43       43
# Aleix ESPARGARO                  124      124
# Aleix VIU                          1        1
# Alen GYORFI                        1        1
# Alessandro ANDREOZZI               7        7
# Alessandro BRANNETTI               1        1
# Alessandro GIORGI                  1        1
# Alessandro TONUCCI                58       58
# Alessio PALUMBO                    1        1
# Alex BALDOLINI                    48       48
# Alex BARROS                       16       16
# Alex DE ANGELIS                   97       97
# Alex DEBON                        39       39
# Alex HOFMANN                      16       16
# Alex MARIÑELARENA                  3        3
# Alex MARQUEZ                      71       71
# Alex RINS                         78       78
# Alexander CUDLIN                   1        1
# Alexander LUNDH                    3        3
# Alexis MASBOU                     80       80
# Alonso LOPEZ                       9        9
# Alvaro BAUTISTA                  136      136
# Alvaro MOLINA                      4        4
# ...                              ...      ...
# Tom TOPARIS                        1        1
# Tommaso GABRIELLI                  2        2
# Tomoyoshi KOYAMA                  61       61
# Toni ELIAS                        75       75
# Toni FINSTERBUSCH                 17       17
# Toni WIRSING                       3        3
# Tony ARBOLINO                     22       22
# Toshihisa KUZUHARA                 4        4
# Troy BAYLISS                       5        5
# Valentin DEBISE                   25       25
# Valentino ROSSI                  155      155
# Vicente PEREZ                      5        5
# Vincent BRAILLARD                 12       12
# Vladimir IVANOV                    9        9
# Vladimir LEONOV                    7        7
# Wai On CHEUNG                      1        1
# Wataru YOSHIKAWA                   1        1
# Xavi CARDELUS                      6        6
# Xavi VIERGE                       34       34
# Xavier SIMEON                     81       81
# Yannick GUERRA                     8        8
# Yari MONTELLA                      1        1
# Yonny HERNANDEZ                   64       64
# Youichi UI                         2        2
# Yuki HAMAMOTO                      1        1
# Yuki TAKAHASHI                    70       70
# Yusuke TESHIMA                     2        2
# Yuuichi YANAGISAWA                 2        2
# Zaqhwan ZAIDI                      4        4
# Zulfahmi KHAIRUDDIN               60       60
#
# [458 rows x 30 columns]

# %%
threshold = 2000000
df[(df.Finish_Time_ms <= threshold)].sample(5)
# Out:
#        Year  TRK                        Track Category Session       Date  \
# 2771   2017  ARA       ARA - MotorLand Aragón    Moto3     RAC 2017-09-24
# 3753   2016  NED       NED - TT Circuit Assen   MotoGP     RAC 2016-06-26
# 1476   2018  VAL  VAL - Circuit Ricardo Tormo   MotoGP    RAC2 2018-11-18
# 13179  2010  GER            GER - Sachsenring   MotoGP     RAC 2010-07-18
# 13191  2010  GER            GER - Sachsenring   MotoGP    RAC2 2010-07-18
#
#       Track_Condition  Track_Temp  Air_Temp  Humidity  ... Left_Corners  \
# 2771              Dry        30.0      22.0      66.0  ...         10.0
# 3753              Wet        20.0      17.0      88.0  ...          6.0
# 1476              Wet        13.0      13.0      98.0  ...          9.0
# 13179             Dry        29.0      20.0      44.0  ...         10.0
# 13191             Dry        31.0      21.0      44.0  ...         10.0
#
#        Right_Corners  track_width length of longest straight MotoGP_avg_speed  \
# 2771             7.0         15.0                      968.0            167.0
# 3753            12.0         14.0                      487.0            173.1
# 1476             5.0         12.0                      876.0            139.8
# 13179            3.0         12.0                      700.0            160.6
# 13191            3.0         12.0                      700.0            160.6
#
#       GP_distance Moto2_distance  Moto3_distance Finish_Time_ms corners
# 2771        116.8          106.6            96.5      1558905.0    17.0
# 3753        118.1          109.0            99.9      1590655.0    18.0
# 1476        108.1          100.1            92.1      1476214.0    14.0
# 13179       110.1          102.8            99.1       760222.0    13.0
# 13191       110.1          102.8            99.1      1765693.0    13.0
#
# [5 rows x 31 columns]

# %%
df_c = df.drop(axis=1, columns=['TRK', 'Track', 'Session', 'Date', 'Position', 'Rider_Name',
                                'Rider_Number', 'Nationality', 'Team_Name', 'Time', 'Finish_Time',
                                'Category', 'Left_Corners', 'Right_Corners', 'Avg_Speed'])

# %%
df = df[df.Finish_Time_ms >= threshold]
plt.figure(figsize=(10,5))
sns.distplot(df.Finish_Time_ms);

# %%
df_rider_mean = (df
                 .groupby(['Rider_Name'])['Points']
                 .mean().reset_index()
                 .sort_values(by='Points', ascending=False)
                )
df_rider_mean.rename(columns={'Points':'points_mean'}, inplace=True)
df_rider_mean.head(20)
# Out:
#            Rider_Name  points_mean
# 63           Can ONCU    25.000000
# 271      Marc MARQUEZ    19.450450
# 66       Casey STONER    17.820896
# 199     Jorge LORENZO    17.678832
# 79       Dani PEDROSA    16.435714
# 422   Valentino ROSSI    16.229730
# 289  Maverick VIÑALES    13.644444
# 184          Joan MIR    13.343750
# 31   Andrea DOVIZIOSO    12.875862
# 22          Alex RINS    12.857143
# 200      Jorge MARTIN    12.258065
# 21       Alex MARQUEZ    11.873016
# 277  Marco SIMONCELLI    11.851852
# 42         Aron CANET    11.695652
# 137    Gabor TALMACSI    11.692308
# 107   Enea BASTIANINI    11.692308
# 290        Max BIAGGI    11.625000
# 304   Miguel OLIVEIRA    11.486842
# 370   Sebastian PORTO    11.444444
# 305       Mika KALLIO    11.385417

# %%
df_merged = df.merge(df_rider_mean)
df_model_prepped = df_merged[["Bike","length of longest straight","Right_Corners","Left_Corners", "Year", "track_width", "MotoGP_avg_speed", "GP_distance", "corners","Rider_Name","points_mean", "Track_Condition", "Track_Temp", "Humidity", "Track","Finish_Time_ms", "Category"]]
df_model_prepped["Rider_Name"] = df_model_prepped["Rider_Name"].apply(lambda x: x.lower())
df_model_prepped["Bike"] = df_model_prepped["Bike"].apply(lambda x: x.lower())
df_model_prepped["Track_Condition"] = df_model_prepped["Track_Condition"].apply(lambda x: x.lower())
df_model_prepped["Track"] = df_model_prepped["Track"].apply(lambda x: x.lower())

#df_model_prepped["Finish_Time_ms"] = round((df_model_prepped["Finish_Time_ms"]/60000),2)
# Out:
# C:\Users\Rconw\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Rconw\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\Rconw\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Rconw\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_merged_encoded = df_model_prepped.copy()
df_merged_encoded.head()
# Out:
#      Bike  length of longest straight  Right_Corners  Left_Corners  Year  \
# 0  ducati                      1068.0           10.0           6.0  2018
# 1  ducati                      1076.0            9.0           5.0  2018
# 2  ducati                      1200.0            9.0          11.0  2018
# 3  ducati                       487.0           12.0           6.0  2018
# 4  ducati                       700.0            3.0          10.0  2018
#
#    track_width  MotoGP_avg_speed  GP_distance  corners        Rider_Name  \
# 0         12.0             166.6        118.4     16.0  andrea dovizioso
# 1         16.0             172.7        120.2     14.0  andrea dovizioso
# 2         15.0             158.4        110.3     20.0  andrea dovizioso
# 3         14.0             173.1        118.1     18.0  andrea dovizioso
# 4         12.0             160.6        110.1     13.0  andrea dovizioso
#
#    points_mean Track_Condition  Track_Temp  Humidity  \
# 0    12.875862             dry        23.0      46.0
# 1    12.875862             wet        23.0      94.0
# 2    12.875862             dry        35.0      45.0
# 3    12.875862             dry        40.0      32.0
# 4    12.875862             dry        48.0      48.0
#
#                                 Track  Finish_Time_ms Category
# 0  qat - losail international circuit       2554654.0   MotoGP
# 1           arg - termas de río hondo       2458875.0   MotoGP
# 2       ame - circuit of the americas       2525572.0   MotoGP
# 3              ned - tt circuit assen       2476285.0   MotoGP
# 4                   ger - sachsenring       2472960.0   MotoGP

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
lbl2 = LabelEncoder()
lbl3 = LabelEncoder()
lbl4 = LabelEncoder()

# %%
# Encoding string based columns
df_merged_encoded["Rider_Name"] = lbl.fit_transform(df_merged_encoded["Rider_Name"])
df_merged_encoded["Bike"] = lbl2.fit_transform(df_merged_encoded["Bike"])
df_merged_encoded["Track_Condition"] = lbl3.fit_transform(df_merged_encoded["Track_Condition"])
df_merged_encoded["Track"] = lbl4.fit_transform(df_merged_encoded["Track"])
#df_merged_encoded.to_csv("model_encoded_data.csv")

# %%
df_merged_encoded = df_merged_encoded[df_merged_encoded.Category == "MotoGP"]
df_merged_encoded.head()
# Out:
#    Bike  length of longest straight  Right_Corners  Left_Corners  Year  \
# 0    12                      1068.0           10.0           6.0  2018
# 1    12                      1076.0            9.0           5.0  2018
# 2    12                      1200.0            9.0          11.0  2018
# 3    12                       487.0           12.0           6.0  2018
# 4    12                       700.0            3.0          10.0  2018
#
#    track_width  MotoGP_avg_speed  GP_distance  corners  Rider_Name  \
# 0         12.0             166.6        118.4     16.0          31
# 1         16.0             172.7        120.2     14.0          31
# 2         15.0             158.4        110.3     20.0          31
# 3         14.0             173.1        118.1     18.0          31
# 4         12.0             160.6        110.1     13.0          31
#
#    points_mean  Track_Condition  Track_Temp  Humidity  Track  Finish_Time_ms  \
# 0    12.875862                0        23.0      46.0     10       2554654.0
# 1    12.875862                1        23.0      94.0      2       2458875.0
# 2    12.875862                0        35.0      45.0      0       2525572.0
# 3    12.875862                0        40.0      32.0      9       2476285.0
# 4    12.875862                0        48.0      48.0      6       2472960.0
#
#   Category
# 0   MotoGP
# 1   MotoGP
# 2   MotoGP
# 3   MotoGP
# 4   MotoGP

# %%
df_merged_encoded = df_merged_encoded.drop(columns=['Category'])

# %%
df_merged_encoded.head()
# Out:
#    Bike  length of longest straight  Right_Corners  Left_Corners  Year  \
# 0    12                      1068.0           10.0           6.0  2018
# 1    12                      1076.0            9.0           5.0  2018
# 2    12                      1200.0            9.0          11.0  2018
# 3    12                       487.0           12.0           6.0  2018
# 4    12                       700.0            3.0          10.0  2018
#
#    track_width  MotoGP_avg_speed  GP_distance  corners  Rider_Name  \
# 0         12.0             166.6        118.4     16.0          31
# 1         16.0             172.7        120.2     14.0          31
# 2         15.0             158.4        110.3     20.0          31
# 3         14.0             173.1        118.1     18.0          31
# 4         12.0             160.6        110.1     13.0          31
#
#    points_mean  Track_Condition  Track_Temp  Humidity  Track  Finish_Time_ms
# 0    12.875862                0        23.0      46.0     10       2554654.0
# 1    12.875862                1        23.0      94.0      2       2458875.0
# 2    12.875862                0        35.0      45.0      0       2525572.0
# 3    12.875862                0        40.0      32.0      9       2476285.0
# 4    12.875862                0        48.0      48.0      6       2472960.0

# %%
df_merged_encoded.to_csv("model_encoded_data.csv")

# %%
import operator
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

df_training = pd.read_csv('model_encoded_data.csv', index_col=0)

x = df_training.drop("Finish_Time_ms", axis = 1)
y = df_training["Finish_Time_ms"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x_train)

model = LinearRegression()
model.fit(x_poly, y_train)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y_train,y_poly_pred))
r2 = r2_score(y_train,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 23652.669969006325
# 0.9732878293621662

# %%
x_poly_test = polynomial_features.fit_transform(x_test)
y_poly_pred = model.predict(x_poly_test)

rmse = np.sqrt(mean_squared_error(y_test,y_poly_pred))
r2 = r2_score(y_test,y_poly_pred)
print(rmse)
print(r2)
# Out:
# 28720.30842122734
# 0.9602122239125654

# %%
# df_training = pd.read_csv('test_csv.csv')

# df_training["rider_mean"] = 12.598361
# df_training["Finish_Time_ms"] =""

# df_training["Rider_Name"] = lbl.fit_transform(df_training ["Rider_Name"])
# df_training["Bike"] = lbl2.fit_transform(df_training ["Bike"])
# df_training["Track_Condition"] = lbl3.fit_transform(df_training ["Track_Condition"])
# df_training["Track"] = lbl4.fit_transform(df_training ["Track"])
# df_training["points_mean"] = 12.598361

# x = df_training.drop("Finish_Time_ms", axis = 1)
# y = df_training["Finish_Time_ms"]

# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2)

# polynomial_features= PolynomialFeatures(degree=3)
# x_poly = polynomial_features.fit_transform(x_train)
# x_poly_test = polynomial_features.fit_transform(x_test)

# y_poly_pred = model.predict(x_poly_test)
# y_poly_pred

# %%
# df_predictions = pd.DataFrame({'Actual': y_test, 'Predicted': y_poly_pred})
# df_predictions["Predicted"] = round(df_predictions["Predicted"],2)
# df_predictions

# %%
df_2019 = pd.read_csv('MotoGP_2019.csv', index_col=0, parse_dates=['Date'])

# %%
# convert finish time into a numerical since it'll be the target of our regression
df_2019['Finish_Time'] = df_2019['Finish_Time'].map(lambda x: pd.to_timedelta(x))
df_2019['Finish_Time_ms'] = df_2019['Finish_Time'].map(lambda x: x/pd.to_timedelta(1, unit='ms'))

# add up left and right corners
df_2019['corners'] = df_2019['Left_Corners'] + df_2019['Right_Corners']

# Use only the motoGP category
df_2019 = df_2019[df_2019.Category == "MotoGP"]

#drop finish outlirer finish times 
df_2019 = df_2019[df_2019.Finish_Time_ms >= threshold]

# drop N/A values
df_2019.dropna(axis = 0, inplace=True)

# %%
df_2019.head()
# Out:
#    Year  TRK                               Track Category Session       Date  \
# 0  2019  QAT  QAT - Losail International Circuit   MotoGP     RAC 2019-03-10
# 1  2019  QAT  QAT - Losail International Circuit   MotoGP     RAC 2019-03-10
# 2  2019  QAT  QAT - Losail International Circuit   MotoGP     RAC 2019-03-10
# 3  2019  QAT  QAT - Losail International Circuit   MotoGP     RAC 2019-03-10
# 4  2019  QAT  QAT - Losail International Circuit   MotoGP     RAC 2019-03-10
#
#   Track_Condition  Track_Temp  Air_Temp  Humidity  ... Left_Corners  \
# 0             Dry          19        18        52  ...            6
# 1             Dry          19        18        52  ...            6
# 2             Dry          19        18        52  ...            6
# 3             Dry          19        18        52  ...            6
# 4             Dry          19        18        52  ...            6
#
#    Right_Corners  track_width length of longest straight  MotoGP_avg_speed  \
# 0             10           12                       1068             166.6
# 1             10           12                       1068             166.6
# 2             10           12                       1068             166.6
# 3             10           12                       1068             166.6
# 4             10           12                       1068             166.6
#
#   GP_distance Moto2_distance Moto3_distance  Finish_Time_ms corners
# 0       118.4          107.6           96.8       2556902.0      16
# 1       118.4          107.6           96.8       2556925.0      16
# 2       118.4          107.6           96.8       2557222.0      16
# 3       118.4          107.6           96.8       2557359.0      16
# 4       118.4          107.6           96.8       2557502.0      16
#
# [5 rows x 32 columns]

# %%
df_2019 = df_2019[["Bike","length of longest straight","Right_Corners","Left_Corners", "Year", "track_width", "MotoGP_avg_speed", "GP_distance", "corners","Rider_Name","points_mean", "Track_Condition", "Track_Temp", "Humidity", "Track","Finish_Time_ms"]]
df_2019["Rider_Name"] = df_2019["Rider_Name"].apply(lambda x: x.lower())
df_2019["Bike"] = df_2019["Bike"].apply(lambda x: x.lower())
df_2019["Track_Condition"] = df_2019["Track_Condition"].apply(lambda x: x.lower())
df_2019["Track"] = df_2019["Track"].apply(lambda x: x.lower())

QAT = ("qat - losail international circuit")
df_2019 = df_2019[(df_2019.Track == QAT)]


# df_2019["Finish_Time_ms"] = round((df_2019["Finish_Time_ms"]/60000),5)
# df_2019.rename(columns={'Finish_Time_ms':'Finish_Time_mins'}, inplace=True)


df_2019.head(35)
# Out:
#        Bike  length of longest straight  Right_Corners  Left_Corners  Year  \
# 0    ducati                        1068             10             6  2019
# 1     honda                        1068             10             6  2019
# 2     honda                        1068             10             6  2019
# 3    suzuki                        1068             10             6  2019
# 4    yamaha                        1068             10             6  2019
# 5    ducati                        1068             10             6  2019
# 6    yamaha                        1068             10             6  2019
# 7    suzuki                        1068             10             6  2019
# 8     honda                        1068             10             6  2019
# 9   aprilia                        1068             10             6  2019
# 10   yamaha                        1068             10             6  2019
# 11      ktm                        1068             10             6  2019
# 12    honda                        1068             10             6  2019
# 13  aprilia                        1068             10             6  2019
# 14      ktm                        1068             10             6  2019
# 15   yamaha                        1068             10             6  2019
# 16      ktm                        1068             10             6  2019
# 17   ducati                        1068             10             6  2019
# 18   ducati                        1068             10             6  2019
# 19      ktm                        1068             10             6  2019
#
#     track_width  MotoGP_avg_speed  GP_distance  corners         Rider_Name  \
# 0            12             166.6        118.4       16   andrea dovizioso
# 1            12             166.6        118.4       16       marc marquez
# 2            12             166.6        118.4       16      cal crutchlow
# 3            12             166.6        118.4       16          alex rins
# 4            12             166.6        118.4       16    valentino rossi
# 5            12             166.6        118.4       16    danilo petrucci
# 6            12             166.6        118.4       16   maverick viñales
# 7            12             166.6        118.4       16           joan mir
# 8            12             166.6        118.4       16   takaaki nakagami
# 9            12             166.6        118.4       16    aleix espargaro
# 10           12             166.6        118.4       16  franco morbidelli
# 11           12             166.6        118.4       16      pol espargaro
# 12           12             166.6        118.4       16      jorge lorenzo
# 13           12             166.6        118.4       16     andrea iannone
# 14           12             166.6        118.4       16       johann zarco
# 15           12             166.6        118.4       16   fabio quartararo
# 16           12             166.6        118.4       16    miguel oliveira
# 17           12             166.6        118.4       16      karel abraham
# 18           12             166.6        118.4       16         tito rabat
# 19           12             166.6        118.4       16     hafizh syahrin
#
#     points_mean Track_Condition  Track_Temp  Humidity  \
# 0     12.598361             dry          19        52
# 1     20.052632             dry          19        52
# 2     10.273973             dry          19        52
# 3     11.647059             dry          19        52
# 4     16.077419             dry          19        52
# 5      6.276923             dry          19        52
# 6     10.320000             dry          19        52
# 7      0.000000             dry          19        52
# 8      3.076923             dry          19        52
# 9      6.530864             dry          19        52
# 10     3.700000             dry          19        52
# 11     7.472727             dry          19        52
# 12    16.923729             dry          19        52
# 13     8.629630             dry          19        52
# 14    10.222222             dry          19        52
# 15     0.000000             dry          19        52
# 16     0.000000             dry          19        52
# 17     2.934783             dry          19        52
# 18     2.793103             dry          19        52
# 19     3.384615             dry          19        52
#
#                                  Track  Finish_Time_ms
# 0   qat - losail international circuit       2556902.0
# 1   qat - losail international circuit       2556925.0
# 2   qat - losail international circuit       2557222.0
# 3   qat - losail international circuit       2557359.0
# 4   qat - losail international circuit       2557502.0
# 5   qat - losail international circuit       2559222.0
# 6   qat - losail international circuit       2559383.0
# 7   qat - losail international circuit       2561990.0
# 8   qat - losail international circuit       2564308.0
# 9   qat - losail international circuit       2566538.0
# 10  qat - losail international circuit       2566549.0
# 11  qat - losail international circuit       2569676.0
# 12  qat - losail international circuit       2571209.0
# 13  qat - losail international circuit       2571251.0
# 14  qat - losail international circuit       2571995.0
# 15  qat - losail international circuit       2572807.0
# 16  qat - losail international circuit       2573279.0
# 17  qat - losail international circuit       2579874.0
# 18  qat - losail international circuit       2579941.0
# 19  qat - losail international circuit       2600144.0

# %%
df_2019["Rider_Name"] = lbl.transform(df_2019["Rider_Name"])
df_2019["Bike"] = lbl2.transform(df_2019["Bike"])
df_2019["Track_Condition"] = lbl3.transform(df_2019["Track_Condition"])
df_2019["Track"] = lbl4.transform(df_2019["Track"])

# %%
df_real = df_2019.copy()
df_real.head()
# Out:
#    Bike  length of longest straight  Right_Corners  Left_Corners  Year  \
# 0    12                        1068             10             6  2019
# 1    24                        1068             10             6  2019
# 2    24                        1068             10             6  2019
# 3    60                        1068             10             6  2019
# 4    68                        1068             10             6  2019
#
#    track_width  MotoGP_avg_speed  GP_distance  corners  Rider_Name  \
# 0           12             166.6        118.4       16          31
# 1           12             166.6        118.4       16         270
# 2           12             166.6        118.4       16          61
# 3           12             166.6        118.4       16          22
# 4           12             166.6        118.4       16         421
#
#    points_mean  Track_Condition  Track_Temp  Humidity  Track  Finish_Time_ms
# 0    12.598361                0          19        52     10       2556902.0
# 1    20.052632                0          19        52     10       2556925.0
# 2    10.273973                0          19        52     10       2557222.0
# 3    11.647059                0          19        52     10       2557359.0
# 4    16.077419                0          19        52     10       2557502.0

# %%
# df_real["Position"] = df_real["Position"].astype(int)
# df_real.dtypes

# %%
x2 = df_real.drop("Finish_Time_ms", axis = 1)
y2 = df_real["Finish_Time_ms"]

polynomial_features= PolynomialFeatures(degree=3)

x_poly_test = polynomial_features.fit_transform(x2)

y_poly_pred = model.predict(x_poly_test)

# %%
df_2019['Rider_Name'] = lbl.inverse_transform(df_2019['Rider_Name'])

df_predictions2 = pd.DataFrame({'Actual': y2, 'Predicted': y_poly_pred})
df_predictions2['Predicted'] = df_predictions2['Predicted']
#df_predictions2['Predicted'] = round(df_predictions2['Predicted'],5)

df_predictions2['Rank'] = df_predictions2['Predicted'].rank()
df_predictions2.round({'Rank': 0})
df_predictions2=df_predictions2.sort_values(by=['Rank'])
df_predictions2['Rider_Name'] = df_2019['Rider_Name']

df_predictions2
# Out:
#        Actual     Predicted  Rank         Rider_Name
# 1   2556925.0  2.545305e+06   1.0       marc marquez
# 3   2557359.0  2.545350e+06   2.0          alex rins
# 4   2557502.0  2.551006e+06   3.0    valentino rossi
# 0   2556902.0  2.551999e+06   4.0   andrea dovizioso
# 6   2559383.0  2.558886e+06   5.0   maverick viñales
# 2   2557222.0  2.560563e+06   6.0      cal crutchlow
# 12  2571209.0  2.562157e+06   7.0      jorge lorenzo
# 10  2566549.0  2.563156e+06   8.0  franco morbidelli
# 9   2566538.0  2.565797e+06   9.0    aleix espargaro
# 5   2559222.0  2.571283e+06  10.0    danilo petrucci
# 13  2571251.0  2.572740e+06  11.0     andrea iannone
# 15  2572807.0  2.574679e+06  12.0   fabio quartararo
# 8   2564308.0  2.575811e+06  13.0   takaaki nakagami
# 11  2569676.0  2.579181e+06  14.0      pol espargaro
# 14  2571995.0  2.579597e+06  15.0       johann zarco
# 17  2579874.0  2.580594e+06  16.0      karel abraham
# 18  2579941.0  2.582313e+06  17.0         tito rabat
# 16  2573279.0  2.583590e+06  18.0    miguel oliveira
# 19  2600144.0  2.583650e+06  19.0     hafizh syahrin
# 7   2561990.0  2.590160e+06  20.0           joan mir

# %%
print(list(zip(model.coef_)))
# Out:
# [(-15.836558451998965,), (1692828.540019082,), (2171327.1036774074,), (1826620.627829071,), (-160206.4063045699,), (646459.1443640069,), (158327.84570484486,), (-2104083.2291441173,), (-3037013.3616969814,), (-276953.2251676501,), (-1909081.4341744024,), (-89472.76540172081,), (-249197.8683051332,), (-161722.57238433833,), (110493.72555661948,), (394256.34595185594,), (1765.9480139718207,), (-253832.9085904589,), (-57577.03962482189,), (-34872.92785044628,), (8646.257216468275,), (-37509.56222418855,), (-5552.437726365092,), (220467.81463681516,), (5238.2524859589485,), (90.17233487522333,), (-1204.5696191912152,), (-205782.50040636724,), (-3415.238267410012,), (1731.4202311804524,), (4223.33884165536,), (6080100.269408226,), (51564.79861242856,), (58560.02826375469,), (-894361.495277841,), (54993.99459302095,), (676246.0303508209,), (325128.5039231706,), (98572.69143692858,), (133549.9292618128,), (107057.83552953467,), (-2076.778936825661,), (110518.76620343016,), (74067.0251944916,), (-48249.23087226539,), (16448.489903876183,), (-737.1018786111894,), (-18239.25856797803,), (14071.721831473027,), (35373.4360268968,), (31180.971297094435,), (2939.95196825518,), (8772.608669831538,), (2157.142219073825,), (2909.997100596179,), (-4171.021070174199,), (401.9447701231824,), (3661.8816621569104,), (3233.174242739599,), (-19859.916167101037,), (3005.3527513879885,), (7250.802154007764,), (7922.416060789928,), (-3808.757452835703,), (2824.939427571109,), (2638.7224674447143,), (-5.041711792643749,), (503.1800631417105,), (1051.372934742895,), (-692.475599823745,), (1277476.9849272827,), (-19092.45219303119,), (-403119.8985992324,), (-247531.9760401689,), (-38661.86937200272,), (-2951.027942511369,), (-148399.24496096224,), (-9788.15492733098,), (-105473.53403162208,), (-132461.91719504015,), (-37575.88520207499,), (-686.5223969823021,), (431.46492047223376,), (4745.866666166919,), (4258.807988083791,), (2156.4197909489926,), (969.2355433335435,), (551.2520702461757,), (439.79072055131394,), (1251.159859495028,), (4290.945628766713,), (-60713.16916510371,), (-3704.9454714961007,), (30496.641407400777,), (19907.86586557379,), (24568.49199832783,), (-403.8088339998498,), (14460.230381905392,), (24360.443922399285,), (-16660.389563294768,), (10894.017211106744,), (22805.684690366383,), (17442.73649816388,), (18320.357422421454,), (-554.1710748744457,), (16082.788920139794,), (18387.213722167664,), (-10628.177697691244,), (7528.1990341264745,), (1743.5720799391975,), (2645.440622454025,), (-519.166766974435,), (1813.1345050822347,), (2368.713345359319,), (446.95771989438884,), (48.87188069580054,), (-268.0789519835082,), (-10729.719367984388,), (11.062837126462057,), (248.47053152731473,), (-489.9429309999449,), (47962.560530761395,), (-1114418.1819544928,), (-9051.377385182255,), (7403.077320543406,), (2182.5331166146593,), (-143.18600567121152,), (-100.62971804584804,), (-232.2554020928664,), (10.837840889558642,), (-152894.45477211417,), (-16347.395303800919,), (690.8121417685019,), (10680.682641229814,), (2242.0677588653502,), (-14376.931588061361,), (-0.9749718982029663,), (0.01564932689507259,), (-141.74109649034676,), (-142.4812361040357,), (-0.7871748896432109,), (-0.3884907053055713,), (0.340489923441055,), (-1.0020333212405603,), (141.01944375444396,), (0.02730746272209217,), (0.20957182346137415,), (6.084974596112886,), (-0.2678851838031733,), (-0.1627835412427885,), (-0.32479774249441107,), (-23.201765973877627,), (7079.632173932566,), (-1088.566326146427,), (0.067809594940627,), (247.73379237154646,), (4278.582656107485,), (-4816.598993039569,), (4922.185863872346,), (-0.001492946918006055,), (0.004874185464359471,), (-0.9036377828498416,), (-0.05845955315635365,), (-0.016610078688245267,), (-2045.3103421280452,), (3224.1241105372137,), (15133.948003507878,), (5015.4375546043775,), (-10221.597866184416,), (-26279.5031349316,), (-14479.275827276995,), (18221.242211553963,), (146.78720340586028,), (-1064.3624174506936,), (-29 ...
